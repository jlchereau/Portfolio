# %% [markdown]
# # Collect Data
#
# This notebook uses a list of tickers to create `./data/features.csv` and `./data/labels.csv` from data found on Yahoo Finance and Zacks.com.

# %% [markdown]
# ## Installation

# %%
#%pip install --upgrade numpy
#%pip install --upgrade pandas
#%pip install --upgrade yfinance

# %%
import numpy as np
import pandas as pd
import yfinance as yf

# %% [markdown]
# ## Tickers
#
# Source: https://github.com/rreichel3/US-Stock-Symbols

# %%
df = pd.read_csv('./data/all_tickers.txt', header=None, dtype=str, keep_default_na=False)
#for index, row in df.iterrows():
#    if type(row[0]) is not str:
#        print(index, row[0])
t = df[0].to_list()
t.sort()
t
# Out:
# ['A',
#  'AA',
#  'AAC',
#  'AACG',
#  'AACI',
#  'AACIU',
#  'AACIW',
#  'AACT',
#  'AADI',
#  'AAIC',
#  'AAIN',
#  'AAL',
#  'AAM',
#  'AAMC',
#  'AAME',
#  'AAN',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAT',
#  'AAU',
#  'AB',
#  'ABBV',
#  'ABC',
#  'ABCB',
#  'ABCL',
#  'ABCM',
#  'ABEO',
#  'ABEV',
#  'ABG',
#  'ABIO',
#  'ABL',
#  'ABLLW',
#  'ABM',
#  'ABNB',
#  'ABOS',
#  'ABR',
#  'ABSI',
#  'ABT',
#  'ABUS',
#  'ABVC',
#  'AC',
#  'ACA',
#  'ACABW',
#  'ACAC',
#  'ACAD',
#  'ACAH',
#  'ACAHU',
#  'ACAHW',
#  'ACAQ',
#  'ACB',
#  'ACBA',
#  'ACBAU',
#  'ACBAW',
#  'ACCD',
#  'ACCO',
#  'ACDC',
#  'ACDCW',
#  'ACEL',
#  'ACER',
#  'ACET',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACGN',
#  'ACHC',
#  'ACHL',
#  'ACHR',
#  'ACHV',
#  'ACI',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACNT',
#  'ACON',
#  'ACONW',
#  'ACOR',
#  'ACP',
#  'ACR',
#  'ACRE',
#  'ACRO',
#  'ACRS',
#  'ACRV',
#  'ACRX',
#  'ACST',
#  'ACT',
#  'ACTG',
#  'ACU',
#  'ACV',
#  'ACVA',
#  'ACXP',
#  'ADAG',
#  'ADAP',
#  'ADBE',
#  'ADC',
#  'ADCT',
#  'ADD',
#  'ADEA',
#  'ADER',
#  'ADERW',
#  'ADES',
#  'ADEX',
#  'ADI',
#  'ADIL',
#  'ADM',
#  'ADMA',
#  'ADMP',
#  'ADN',
#  'ADNT',
#  'ADNWW',
#  'ADOC',
#  'ADOCR',
#  'ADOCW',
#  'ADP',
#  'ADPT',
#  'ADRT',
#  'ADSE',
#  'ADSEW',
#  'ADSK',
#  'ADT',
#  'ADTH',
#  'ADTHW',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'ADX',
#  'ADXN',
#  'AE',
#  'AEAE',
#  'AEAEU',
#  'AEAEW',
#  'AEE',
#  'AEF',
#  'AEFC',
#  'AEG',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEL',
#  'AEM',
#  'AEMD',
#  'AENT',
#  'AENTW',
#  'AENZ',
#  'AEO',
#  'AEON',
#  'AEP',
#  'AEPPZ',
#  'AER',
#  'AES',
#  'AESC',
#  'AESI',
#  'AEVA',
#  'AEY',
#  'AEYE',
#  'AEZS',
#  'AFAR',
#  'AFARU',
#  'AFB',
#  'AFBI',
#  'AFCG',
#  'AFG',
#  'AFGB',
#  'AFGC',
#  'AFGD',
#  'AFGE',
#  'AFIB',
#  'AFL',
#  'AFMD',
#  'AFRI',
#  'AFRIW',
#  'AFRM',
#  'AFT',
#  'AFTR',
#  'AFYA',
#  'AG',
#  'AGAC',
#  'AGAE',
#  'AGBA',
#  'AGBAW',
#  'AGCO',
#  'AGD',
#  'AGE',
#  'AGEN',
#  'AGFY',
#  'AGI',
#  'AGIL',
#  'AGIO',
#  'AGL',
#  'AGLE',
#  'AGM',
#  'AGMH',
#  'AGNC',
#  'AGNCL',
#  'AGNCM',
#  'AGNCN',
#  'AGNCO',
#  'AGNCP',
#  'AGO',
#  'AGR',
#  'AGRI',
#  'AGRIW',
#  'AGRO',
#  'AGRX',
#  'AGS',
#  'AGTI',
#  'AGX',
#  'AGYS',
#  'AHCO',
#  'AHG',
#  'AHH',
#  'AHI',
#  'AHL',
#  'AHT',
#  'AI',
#  'AIB',
#  'AIC',
#  'AIF',
#  'AIG',
#  'AIH',
#  'AIHS',
#  'AIM',
#  'AIMBU',
#  'AIMD',
#  'AIMDW',
#  'AIN',
#  'AINC',
#  'AIO',
#  'AIP',
#  'AIR',
#  'AIRC',
#  'AIRG',
#  'AIRI',
#  'AIRS',
#  'AIRT',
#  'AIRTP',
#  'AIT',
#  'AIU',
#  'AIV',
#  'AIXI',
#  'AIZ',
#  'AIZN',
#  'AJG',
#  'AJX',
#  'AJXA',
#  'AKA',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKLI',
#  'AKO',
#  'AKR',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKU',
#  'AKYA',
#  'AL',
#  'ALAR',
#  'ALB',
#  'ALBT',
#  'ALC',
#  'ALCC',
#  'ALCO',
#  'ALCY',
#  'ALCYU',
#  'ALCYW',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALEX',
#  'ALG',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIM',
#  'ALIT',
#  'ALK',
#  'ALKS',
#  'ALKT',
#  'ALL',
#  'ALLE',
#  'ALLG',
#  'ALLK',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALLY',
#  'ALNY',
#  'ALOR',
#  'ALOT',
#  'ALPN',
#  'ALPP',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALSA',
#  'ALSAR',
#  'ALSAW',
#  'ALSN',
#  'ALT',
#  'ALTG',
#  'ALTI',
#  'ALTO',
#  'ALTR',
#  'ALTU',
#  'ALTUW',
#  'ALUR',
#  'ALV',
#  'ALVO',
#  'ALVOW',
#  'ALVR',
#  'ALX',
#  'ALXO',
#  'ALYA',
#  'ALZN',
#  'AM',
#  'AMAL',
#  'AMAM',
#  'AMAO',
#  'AMAOU',
#  'AMAOW',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMBI',
#  'AMBO',
#  'AMBP',
#  'AMC',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMEH',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMK',
#  'AMKR',
#  'AMLI',
#  'AMLX',
#  'AMN',
#  'AMNB',
#  'AMOT',
#  'AMP',
#  'AMPE',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMPS',
#  'AMPX',
#  'AMPY',
#  'AMR',
#  'AMRC',
#  'AMRK',
#  'AMRN',
#  'AMRS',
#  'AMRX',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMSWA',
#  'AMT',
#  'AMTB',
#  'AMTD',
#  'AMTI',
#  'AMTX',
#  'AMWD',
#  'AMWL',
#  'AMX',
#  'AMZN',
#  'AN',
#  'ANAB',
#  'ANDE',
#  'ANEB',
#  'ANET',
#  'ANF',
#  'ANGH',
#  'ANGHW',
#  'ANGI',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANSS',
#  'ANTE',
#  'ANTX',
#  'ANVS',
#  'ANY',
#  'ANZU',
#  'ANZUU',
#  'ANZUW',
#  'AOD',
#  'AOGO',
#  'AOGOW',
#  'AOMR',
#  'AON',
#  'AORT',
#  'AOS',
#  'AOSL',
#  'AOUT',
#  'AP',
#  'APA',
#  'APAC',
#  'APAM',
#  'APCA',
#  'APCX',
#  'APCXW',
#  'APD',
#  'APDN',
#  'APE',
#  'APEI',
#  'APG',
#  'APGB',
#  'APGE',
#  'APGN',
#  'APGNW',
#  'APH',
#  'API',
#  'APLD',
#  'APLE',
#  'APLM',
#  'APLMW',
#  'APLS',
#  'APLT',
#  'APM',
#  'APMI',
#  'APMIU',
#  'APMIW',
#  'APO',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APRE',
#  'APRN',
#  'APT',
#  'APTM',
#  'APTMU',
#  'APTMW',
#  'APTO',
#  'APTV',
#  'APVO',
#  'APWC',
#  'APXI',
#  'APXIW',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQN',
#  'AQNA',
#  'AQNB',
#  'AQNU',
#  'AQST',
#  'AQUNR',
#  'AR',
#  'ARAV',
#  'ARAY',
#  'ARBB',
#  'ARBE',
#  'ARBEW',
#  'ARBK',
#  'ARBKL',
#  'ARC',
#  'ARCB',
#  'ARCC',
#  'ARCE',
#  'ARCH',
#  'ARCO',
#  'ARCT',
#  'ARDC',
#  'ARDX',
#  'ARE',
#  'AREB',
#  'AREBW',
#  'AREC',
#  'AREN',
#  'ARES',
#  'ARGD',
#  'ARGO',
#  'ARGX',
#  'ARHS',
#  'ARI',
#  'ARIS',
#  'ARIZ',
#  'ARIZW',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARL',
#  'ARLO',
#  'ARLP',
#  'ARMK',
#  'ARMP',
#  'ARNC',
#  'AROC',
#  'AROW',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARR',
#  'ARRW',
#  'ARRWU',
#  'ARRWW',
#  'ARRY',
#  'ARTE',
#  'ARTEW',
#  'ARTL',
#  'ARTLW',
#  'ARTNA',
#  'ARTW',
#  'ARVL',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'ARYD',
#  'ASA',
#  'ASAI',
#  'ASAN',
#  'ASB',
#  'ASBA',
#  'ASC',
#  'ASCA',
#  'ASCAR',
#  'ASCB',
#  'ASCBR',
#  'ASCBU',
#  'ASG',
#  'ASGI',
#  'ASGN',
#  'ASH',
#  'ASIX',
#  'ASLE',
#  'ASLN',
#  'ASM',
#  'ASMB',
#  'ASML',
#  'ASND',
#  'ASNS',
#  'ASO',
#  'ASPA',
#  'ASPAU',
#  'ASPI',
#  'ASPN',
#  'ASPS',
#  'ASR',
#  'ASRT',
#  'ASRV',
#  'ASST',
#  'ASTC',
#  'ASTE',
#  'ASTI',
#  'ASTL',
#  'ASTLW',
#  'ASTR',
#  'ASTS',
#  'ASTSW',
#  'ASUR',
#  'ASX',
#  'ASXC',
#  'ASYS',
#  'ATAI',
#  'ATAK',
#  'ATAKR',
#  'ATAKU',
#  'ATAKW',
#  'ATAQ',
#  'ATAT',
#  'ATCO',
#  'ATCOL',
#  'ATEC',
#  'ATEK',
#  'ATEN',
#  'ATER',
#  'ATEX',
#  'ATGE',
#  'ATH',
#  'ATHA',
#  'ATHE',
#  'ATHM',
#  'ATHX',
#  'ATI',
#  'ATIF',
#  'ATIP',
#  'ATKR',
#  'ATLC',
#  'ATLCL',
#  'ATLCP',
#  'ATLO',
#  'ATLX',
#  'ATMC',
#  'ATMCR',
#  'ATMCW',
#  'ATMU',
#  'ATMV',
#  'ATMVU',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATNM',
#  'ATO',
#  'ATOM',
#  'ATOS',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRI',
#  'ATRO',
#  'ATS',
#  'ATSG',
#  'ATUS',
#  'ATVI',
#  'ATXG',
#  'ATXI',
#  'ATXS',
#  'AU',
#  'AUB',
#  'AUBN',
#  'AUDC',
#  'AUGX',
#  'AUID',
#  'AULT',
#  'AUMN',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AURC',
#  'AURCU',
#  'AURCW',
#  'AUROW',
#  'AUST',
#  'AUTL',
#  'AUUD',
#  'AUUDW',
#  'AUVI',
#  'AUVIP',
#  'AVA',
#  'AVAH',
#  'AVAL',
#  'AVAV',
#  'AVB',
#  'AVD',
#  'AVDL',
#  'AVDX',
#  'AVGO',
#  'AVGR',
#  'AVHI',
#  'AVID',
#  'AVIR',
#  'AVK',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVRO',
#  'AVT',
#  'AVTA',
#  'AVTE',
#  'AVTR',
#  'AVTX',
#  'AVXL',
#  'AVY',
#  'AWF',
#  'AWH',
#  'AWI',
#  'AWIN',
#  'AWINW',
#  'AWK',
#  'AWP',
#  'AWR',
#  'AWRE',
#  'AWX',
#  'AX',
#  'AXDX',
#  'AXGN',
#  'AXL',
#  'AXLA',
#  'AXNX',
#  'AXON',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXSM',
#  'AXTA',
#  'AXTI',
#  'AY',
#  'AYI',
#  'AYRO',
#  'AYTU',
#  'AYX',
#  'AZ',
#  'AZEK',
#  'AZN',
#  'AZO',
#  'AZPN',
#  'AZTA',
#  'AZTR',
#  'AZUL',
#  'AZYO',
#  'AZZ',
#  'B',
#  'BA',
#  'BABA',
#  'BAC',
#  'BACA',
#  'BACK',
#  'BAER',
#  'BAERW',
#  'BAFN',
#  'BAH',
#  'BAK',
#  'BALL',
#  'BALY',
#  'BAM',
#  'BANC',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANL',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BAP',
#  'BARK',
#  'BASE',
#  'BATL',
#  'BATRA',
#  'BATRK',
#  'BAX',
#  'BB',
#  'BBAI',
#  'BBAR',
#  'BBCP',
#  'BBD',
#  'BBDC',
#  'BBDO',
#  'BBGI',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBN',
#  'BBSI',
#  'BBU',
#  'BBUC',
#  'BBVA',
#  'BBW',
#  'BBWI',
#  'BBY',
#  'BC',
#  'BCAB',
#  'BCAL',
#  'BCAN',
#  'BCAT',
#  'BCBP',
#  'BCC',
#  'BCDA',
#  'BCDAW',
#  'BCE',
#  'BCEL',
#  'BCH',
#  'BCLI',
#  'BCML',
#  'BCO',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCS',
#  'BCSA',
#  'BCSAU',
#  'BCSAW',
#  'BCSF',
#  'BCTX',
#  'BCTXW',
#  'BCV',
#  'BCX',
#  'BCYC',
#  'BDC',
#  'BDJ',
#  'BDL',
#  'BDN',
#  'BDRX',
#  'BDSX',
#  'BDTX',
#  'BDX',
#  'BE',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BECN',
#  'BEDU',
#  'BEEM',
#  'BEEMW',
#  'BEKE',
#  'BELFA',
#  'BELFB',
#  'BEN',
#  'BENF',
#  'BENFW',
#  'BEP',
#  'BEPC',
#  'BEPH',
#  'BEPI',
#  'BERY',
#  'BEST',
#  'BF',
#  'BFAC',
#  'BFAM',
#  'BFC',
#  'BFH',
#  'BFI',
#  'BFIIW',
#  'BFIN',
#  'BFK',
#  'BFLY',
#  'BFRG',
#  'BFRGW',
#  'BFRI',
#  'BFRIW',
#  'BFS',
#  'BFST',
#  'BFZ',
#  'BG',
#  'BGB',
#  'BGC',
#  'BGFV',
#  'BGH',
#  'BGI',
#  'BGLC',
#  'BGNE',
#  'BGR',
#  'BGS',
#  'BGSF',
#  'BGT',
#  'BGX',
#  'BGXX',
#  'BGY',
#  'BH',
#  'BHAC',
#  'BHAT',
#  'BHB',
#  'BHC',
#  'BHE',
#  'BHF',
#  'BHFAL',
#  'BHFAM',
#  'BHFAN',
#  'BHFAO',
#  'BHFAP',
#  'BHG',
#  'BHIL',
#  'BHK',
#  'BHLB',
#  'BHM',
#  'BHP',
#  'BHR',
#  'BHRB',
#  'BHV',
#  'BHVN',
#  'BIAF',
#  'BIAFW',
#  'BIDU',
#  'BIG',
#  'BIGC',
#  'BIGZ',
#  'BIIB',
#  'BILI',
#  'BILL',
#  'BIMI',
#  'BIO',
#  'BIOC',
#  'BIOL',
#  'BIOR',
#  'BIOS',
#  'BIOSU',
#  'BIOSW',
#  'BIOX',
#  'BIP',
#  'BIPC',
#  'BIPH',
#  'BIPI',
#  'BIRD',
#  'BIT',
#  'BITE',
#  'BITF',
#  'BIVI',
#  'BJ',
#  'BJDX',
#  'BJRI',
#  'BK',
#  'BKCC',
#  'BKD',
#  'BKDT',
#  'BKE',
#  'BKH',
#  'BKI',
#  'BKKT',
#  'BKN',
#  'BKNG',
#  'BKR',
#  'BKSC',
#  'BKSY',
#  'BKT',
#  'BKTI',
#  'BKU',
#  'BKYI',
#  'BL',
#  'BLAC',
#  'BLACR',
#  'BLACU',
#  'BLACW',
#  'BLBD',
#  'BLBX',
#  'BLCO',
#  'BLD',
#  'BLDE',
#  'BLDEW',
#  'BLDP',
#  'BLDR',
#  'BLE',
#  'BLEU',
#  'BLEUR',
#  'BLEUW',
#  'BLFS',
#  'BLFY',
#  'BLIN',
#  'BLK',
#  'BLKB',
#  'BLMN',
#  'BLND',
#  'BLNK',
#  'BLPH',
#  'BLRX',
#  'BLTE',
#  'BLUA',
#  'BLUE',
#  'BLW',
#  'BLX',
#  'BLZE',
#  'BMA',
#  'BMAC',
#  'BMBL',
#  'BME',
#  'BMEA',
#  'BMEZ',
#  'BMI',
#  'BML',
#  'BMN',
#  'BMO',
#  'BMR',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BMTX',
#  'BMY',
#  'BN',
#  'BNED',
#  'BNGO',
#  'BNGOW',
#  'BNH',
#  'BNIX',
#  'BNIXR',
#  'BNIXW',
#  'BNJ',
#  'BNL',
#  'BNMV',
#  'BNOX',
#  'BNR',
#  'BNRE',
#  'BNRG',
#  'BNS',
#  'BNTC',
#  'BNTX',
#  'BNY',
#  'BOAC',
#  'BOC',
#  'BOCN',
#  'BOCNW',
#  'BODY',
#  'BOE',
#  'BOF',
#  ...]

# %% [markdown]
# ## Features
#
# Collect feature data from Yahoo Finance, using:
#
# - https://github.com/ranaroussi/yfinance

# %%
ticker = yf.Ticker('MSFT')
#ticker.actions
#ticker.dividends
#ticher.history(period='5y')
ticker.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software—Infrastructure',
#  'industryDisp': 'Software—Infrastructure',
#  'sector': 'Technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Microsoft Corporation develops and supports software, services, devices and solutions worldwide. The Productivity and Business Processes segment offers office, exchange, SharePoint, Microsoft Teams, office 365 Security and Compliance, Microsoft viva, and Microsoft 365 copilot; and office consumer services, such as Microsoft 365 consumer subscriptions, Office licensed on-premises, and other office services. This segment also provides LinkedIn; and dynamics business solutions, including Dynamics 365, a set of intelligent, cloud-based applications across ERP, CRM, power apps, and power automate; and on-premises ERP and CRM applications. The Intelligent Cloud segment provides server products and cloud services, such as azure and other cloud services; SQL and windows server, visual studio, system center, and related client access licenses, as well as nuance and GitHub; and enterprise services including enterprise support services, industry solutions, and nuance professional services. The More Personal Computing segment offers Windows, including windows OEM licensing and other non-volume licensing of the Windows operating system; Windows commercial comprising volume licensing of the Windows operating system, windows cloud services, and other Windows commercial offerings; patent licensing; and windows Internet of Things; and devices, such as surface, HoloLens, and PC accessories. Additionally, this segment provides gaming, which includes Xbox hardware and content, and first- and third-party content; Xbox game pass and other subscriptions, cloud gaming, advertising, third-party disc royalties, and other cloud services; and search and news advertising, which includes Bing, Microsoft News and Edge, and third-party affiliates. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online, and retail stores. The company was founded in 1975 and is headquartered in Redmond, Washington.',
#  'fullTimeEmployees': 221000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Satya  Nadella',
#    'age': 55,
#    'title': 'Chairman & CEO',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 12676750,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Bradford L. Smith LCA',
#    'age': 63,
#    'title': 'Pres & Vice Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2022,
#    'totalPay': 4655274,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Amy E. Hood',
#    'age': 50,
#    'title': 'Exec. VP & CFO',
#    'yearBorn': 1972,
#    'fiscalYear': 2022,
#    'totalPay': 4637915,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Judson  Althoff',
#    'age': 49,
#    'title': 'Exec. VP & Chief Commercial Officer',
#    'yearBorn': 1973,
#    'fiscalYear': 2022,
#    'totalPay': 4428268,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher David Young',
#    'age': 50,
#    'title': 'Exec. VP of Bus. Devel., Strategy & Ventures',
#    'yearBorn': 1972,
#    'fiscalYear': 2022,
#    'totalPay': 4588876,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alice L. Jolla',
#    'age': 55,
#    'title': 'Corp. VP & Chief Accounting Officer',
#    'yearBorn': 1967,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James Kevin Scott',
#    'age': 50,
#    'title': 'Exec. VP of AI & CTO',
#    'yearBorn': 1972,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Brett  Iversen',
#    'title': 'Gen. Mang. of Investor Relations',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Frank X. Shaw',
#    'title': 'Corp. VP for Corp. Communications',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Christopher C. Capossela',
#    'age': 52,
#    'title': 'Exec. VP & Chief Marketing Officer',
#    'yearBorn': 1970,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 6,
#  'boardRisk': 3,
#  'compensationRisk': 3,
#  'shareHolderRightsRisk': 2,
#  'overallRisk': 2,
#  'governanceEpochDate': 1690848000,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 330.11,
#  'open': 326.96,
#  'dayLow': 323.0,
#  'dayHigh': 328.75,
#  'regularMarketPreviousClose': 330.11,
#  'regularMarketOpen': 326.96,
#  'regularMarketDayLow': 323.0,
#  'regularMarketDayHigh': 328.75,
#  'dividendRate': 2.72,
#  'dividendYield': 0.0083,
#  'exDividendDate': 1692144000,
#  'payoutRatio': 0.2748,
#  'fiveYearAvgDividendYield': 1.06,
#  'beta': 0.903706,
#  'trailingPE': 35.325027,
#  'forwardPE': 28.475983,
#  'volume': 22202809,
#  'regularMarketVolume': 22202809,
#  'averageVolume': 28707061,
#  'averageVolume10days': 28004720,
#  'averageDailyVolume10Day': 28004720,
#  'bid': 0.0,
#  'ask': 0.0,
#  'bidSize': 900,
#  'askSize': 800,
#  'marketCap': 2424341266432,
#  'fiftyTwoWeekLow': 213.43,
#  'fiftyTwoWeekHigh': 366.78,
#  'priceToSalesTrailing12Months': 11.440159,
#  'fiftyDayAverage': 336.5732,
#  'twoHundredDayAverage': 280.49026,
#  'trailingAnnualDividendRate': 2.72,
#  'trailingAnnualDividendYield': 0.008239678,
#  'currency': 'USD',
#  'enterpriseValue': 2403512877056,
#  'profitMargins': 0.34146,
#  'floatShares': 7423745613,
#  'sharesOutstanding': 7435489792,
#  'sharesShort': 42497800,
#  'sharesShortPriorMonth': 44270818,
#  'sharesShortPreviousMonthDate': 1686787200,
#  'dateShortInterest': 1689292800,
#  'sharesPercentSharesOut': 0.0057,
#  'heldPercentInsiders': 0.00052,
#  'heldPercentInstitutions': 0.73212,
#  'shortRatio': 1.66,
#  'shortPercentOfFloat': 0.0057,
#  'impliedSharesOutstanding': 0,
#  'bookValue': 27.748,
#  'priceToBook': 11.750397,
#  'lastFiscalYearEnd': 1688083200,
#  'nextFiscalYearEnd': 1719705600,
#  'mostRecentQuarter': 1688083200,
#  'earningsQuarterlyGrowth': 0.2,
#  'netIncomeToCommon': 72361000960,
#  'trailingEps': 9.23,
#  'forwardEps': 11.45,
#  'pegRatio': 2.53,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1045526400,
#  'enterpriseToRevenue': 11.342,
#  'enterpriseToEbitda': 23.559,
#  '52WeekChange': 0.12757647,
#  'SandP52WeekChange': 0.0686754,
#  'lastDividendValue': 0.68,
#  'lastDividendDate': 1684281600,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'MSFT',
#  'underlyingSymbol': 'MSFT',
#  'shortName': 'Microsoft Corporation',
#  'longName': 'Microsoft Corporation',
#  'firstTradeDateEpochUtc': 511108200,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EDT',
#  'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#  'messageBoardId': 'finmb_21835',
#  'gmtOffSetMilliseconds': -14400000,
#  'currentPrice': 326.05,
#  'targetHighPrice': 393.9,
#  'targetLowPrice': 210.86,
#  'targetMeanPrice': 351.81,
#  'targetMedianPrice': 363.55,
#  'recommendationMean': 1.8,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 44,
#  'totalCash': 111256002560,
#  'totalCashPerShare': 14.974,
#  'ebitda': 102022995968,
#  'totalDebt': 79441002496,
#  'quickRatio': 1.536,
#  'currentRatio': 1.769,
#  'totalRevenue': 211914997760,
#  'debtToEquity': 38.522,
#  'revenuePerShare': 28.46,
#  'returnOnAssets': 0.14245,
#  'returnOnEquity': 0.38824,
#  'freeCashflow': 47268999168,
#  'operatingCashflow': 87581999104,
#  'earningsGrowth': 0.202,
#  'revenueGrowth': 0.083,
#  'grossMargins': 0.6892,
#  'ebitdaMargins': 0.48143002,
#  'operatingMargins': 0.41772997,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.3916}

# %% [markdown]
# Most relevant features (columns) are listed at:
#
# - https://yourfinancebook.com/stock-market-financial-metrics/

# %%
columns = [
    'shortName',
    'sector',
    'industry',
    # Stock metrics
    'recommendationMean',
    'overallRisk',
    'beta',
    # Earnings per Share (EPS)
    'trailingEps',
    'forwardEps',
    # Price to earnings ratio (P/E)
    'trailingPE',
    'forwardPE',
    #'trailingPegRatio',
    'pegRatio',
    # Price to book value ratio (P/B)
    'bookValue',
    'priceToBook',
    # Profit margin
    'ebitdaMargins',
    'profitMargins',
    'earningsGrowth',
    'revenueGrowth',
    # Dividend payout ratio and Dividend yield
    # 'dividendRate',
    'dividendYield',
    'payoutRatio',
    'fiveYearAvgDividendYield',
    # Price to free cash flow ratio
    # ?
    # Debt to equity ratio (DE)
    'debtToEquity',
    # Return on assets (ROA)
    'returnOnAssets',
    # Return on equity (ROE)
    'returnOnEquity',
    # Quick and current ratios
    'quickRatio',
    'currentRatio',
]

features = pd.DataFrame(index = t, columns=columns)

for idx in features.index:
    ticker = yf.Ticker(idx)
    try:
        info = ticker.info
        for c in columns: 
            try:
                features.loc[idx, [c]] = info[c]
            except Exception as e:
                print (idx, e) # This yields a NaN
    except Exception as e:
        print (idx, e)
features
# Out:
# AA 'trailingPE'
# AA 'earningsGrowth'
# AA 'payoutRatio'
# AA 'fiveYearAvgDividendYield'
# AAC 'recommendationMean'
# AAC 'overallRisk'
# AAC 'trailingPE'
# AAC 'pegRatio'
# AAC 'priceToBook'
# AAC 'earningsGrowth'
# AAC 'revenueGrowth'
# AAC 'dividendYield'
# AAC 'fiveYearAvgDividendYield'
# AAC 'debtToEquity'
# AAC 'returnOnEquity'
# AACG 'overallRisk'
# AACG 'trailingPE'
# AACG 'earningsGrowth'
# AACG 'dividendYield'
# AACG 'fiveYearAvgDividendYield'
# AACI 'recommendationMean'
# AACI 'overallRisk'
# AACI 'beta'
# AACI 'forwardEps'
# AACI 'trailingPE'
# AACI 'forwardPE'
# AACI 'pegRatio'
# AACI 'priceToBook'
# AACI 'earningsGrowth'
# AACI 'revenueGrowth'
# AACI 'dividendYield'
# AACI 'fiveYearAvgDividendYield'
# AACI 'debtToEquity'
# AACI 'returnOnEquity'
# AACIU 'recommendationMean'
# AACIU 'overallRisk'
# AACIU 'beta'
# AACIU 'forwardEps'
# AACIU 'trailingPE'
# AACIU 'forwardPE'
# AACIU 'pegRatio'
# AACIU 'priceToBook'
# AACIU 'earningsGrowth'
# AACIU 'revenueGrowth'
# AACIU 'dividendYield'
# AACIU 'payoutRatio'
# AACIU 'fiveYearAvgDividendYield'
# AACIU 'debtToEquity'
# AACIU 'returnOnEquity'
# AACIW 'sector'
# AACIW 'industry'
# AACIW 'recommendationMean'
# AACIW 'overallRisk'
# AACIW 'beta'
# AACIW 'trailingEps'
# AACIW 'forwardEps'
# AACIW 'trailingPE'
# AACIW 'forwardPE'
# AACIW 'pegRatio'
# AACIW 'bookValue'
# AACIW 'priceToBook'
# AACIW 'ebitdaMargins'
# AACIW 'profitMargins'
# AACIW 'earningsGrowth'
# AACIW 'revenueGrowth'
# AACIW 'dividendYield'
# AACIW 'payoutRatio'
# AACIW 'fiveYearAvgDividendYield'
# AACIW 'debtToEquity'
# AACIW 'returnOnAssets'
# AACIW 'returnOnEquity'
# AACIW 'quickRatio'
# AACIW 'currentRatio'
# AACT 'recommendationMean'
# AACT 'overallRisk'
# AACT 'beta'
# AACT 'forwardEps'
# AACT 'forwardPE'
# AACT 'pegRatio'
# AACT 'earningsGrowth'
# AACT 'revenueGrowth'
# AACT 'dividendYield'
# AACT 'fiveYearAvgDividendYield'
# AACT 'returnOnAssets'
# AACT 'returnOnEquity'
# AACT 'quickRatio'
# AADI 'beta'
# AADI 'trailingPE'
# AADI 'pegRatio'
# AADI 'earningsGrowth'
# AADI 'dividendYield'
# AADI 'fiveYearAvgDividendYield'
# AAIC 'earningsGrowth'
# AAIC 'dividendYield'
# AAIC 'fiveYearAvgDividendYield'
# AAIN 'sector'
# AAIN 'industry'
# AAIN 'recommendationMean'
# AAIN 'overallRisk'
# AAIN 'beta'
# AAIN 'trailingEps'
# AAIN 'forwardEps'
# AAIN 'trailingPE'
# AAIN 'forwardPE'
# AAIN 'pegRatio'
# AAIN 'bookValue'
# AAIN 'priceToBook'
# AAIN 'ebitdaMargins'
# AAIN 'profitMargins'
# AAIN 'earningsGrowth'
# AAIN 'revenueGrowth'
# AAIN 'dividendYield'
# AAIN 'payoutRatio'
# AAIN 'fiveYearAvgDividendYield'
# AAIN 'debtToEquity'
# AAIN 'returnOnAssets'
# AAIN 'returnOnEquity'
# AAIN 'quickRatio'
# AAIN 'currentRatio'
# AAL 'priceToBook'
# AAL 'dividendYield'
# AAL 'fiveYearAvgDividendYield'
# AAL 'debtToEquity'
# AAL 'returnOnEquity'
# AAM 'shortName'
# AAM 'sector'
# AAM 'industry'
# AAM 'recommendationMean'
# AAM 'overallRisk'
# AAM 'beta'
# AAM 'trailingEps'
# AAM 'forwardEps'
# AAM 'trailingPE'
# AAM 'forwardPE'
# AAM 'pegRatio'
# AAM 'bookValue'
# AAM 'priceToBook'
# AAM 'ebitdaMargins'
# AAM 'profitMargins'
# AAM 'earningsGrowth'
# AAM 'revenueGrowth'
# AAM 'dividendYield'
# AAM 'payoutRatio'
# AAM 'fiveYearAvgDividendYield'
# AAM 'debtToEquity'
# AAM 'returnOnAssets'
# AAM 'returnOnEquity'
# AAM 'quickRatio'
# AAM 'currentRatio'
# AAMC 'recommendationMean'
# AAMC 'overallRisk'
# AAMC 'forwardEps'
# AAMC 'trailingPE'
# AAMC 'forwardPE'
# AAMC 'pegRatio'
# AAMC 'priceToBook'
# AAMC 'earningsGrowth'
# AAMC 'revenueGrowth'
# AAMC 'dividendYield'
# AAMC 'fiveYearAvgDividendYield'
# AAME 'recommendationMean'
# AAME 'forwardEps'
# AAME 'trailingPE'
# AAME 'forwardPE'
# AAME 'pegRatio'
# AAME 'earningsGrowth'
# AAME 'dividendYield'
# AAME 'payoutRatio'
# AAME 'fiveYearAvgDividendYield'
# AAN 'trailingPE'
# AAN 'earningsGrowth'
# AAN 'payoutRatio'
# AAN 'fiveYearAvgDividendYield'
# AAOI 'trailingPE'
# AAOI 'earningsGrowth'
# AAOI 'dividendYield'
# AAOI 'fiveYearAvgDividendYield'
# AAU 'overallRisk'
# AAU 'trailingPE'
# AAU 'pegRatio'
# AAU 'earningsGrowth'
# AAU 'revenueGrowth'
# AAU 'dividendYield'
# AAU 'fiveYearAvgDividendYield'
# AB 'overallRisk'
# AB 'revenueGrowth'
# AB 'debtToEquity'
# AB 'returnOnAssets'
# AB 'quickRatio'
# AB 'currentRatio'
# ABBV 'returnOnAssets'
# ABBV 'returnOnEquity'
# ABBV 'quickRatio'
# ABBV 'currentRatio'
# ABCB 'debtToEquity'
# ABCB 'quickRatio'
# ABCB 'currentRatio'
# ABCL 'trailingPE'
# ABCL 'earningsGrowth'
# ABCL 'dividendYield'
# ABCL 'fiveYearAvgDividendYield'
# ABCM 'overallRisk'
# ABCM 'forwardEps'
# ABCM 'trailingPE'
# ABCM 'forwardPE'
# ABCM 'pegRatio'
# ABCM 'earningsGrowth'
# ABCM 'dividendYield'
# ABCM 'fiveYearAvgDividendYield'
# ABEO 'overallRisk'
# ABEO 'trailingPE'
# ABEO 'pegRatio'
# ABEO 'earningsGrowth'
# ABEO 'revenueGrowth'
# ABEO 'dividendYield'
# ABEO 'fiveYearAvgDividendYield'
# ABEV 'beta'
# ABG 'dividendYield'
# ABG 'fiveYearAvgDividendYield'
# ABIO 'recommendationMean'
# ABIO 'overallRisk'
# ABIO 'trailingPE'
# ABIO 'pegRatio'
# ABIO 'earningsGrowth'
# ABIO 'revenueGrowth'
# ABIO 'dividendYield'
# ABIO 'fiveYearAvgDividendYield'
# ABL 'recommendationMean'
# ABL 'overallRisk'
# ABL 'forwardEps'
# ABL 'trailingPE'
# ABL 'forwardPE'
# ABL 'pegRatio'
# ABL 'earningsGrowth'
# ABL 'dividendYield'
# ABL 'fiveYearAvgDividendYield'
# ABL 'returnOnAssets'
# ABLLW 'shortName'
# ABLLW 'sector'
# ABLLW 'industry'
# ABLLW 'recommendationMean'
# ABLLW 'overallRisk'
# ABLLW 'beta'
# ABLLW 'trailingEps'
# ABLLW 'forwardEps'
# ABLLW 'trailingPE'
# ABLLW 'forwardPE'
# ABLLW 'pegRatio'
# ABLLW 'bookValue'
# ABLLW 'priceToBook'
# ABLLW 'ebitdaMargins'
# ABLLW 'profitMargins'
# ABLLW 'earningsGrowth'
# ABLLW 'revenueGrowth'
# ABLLW 'dividendYield'
# ABLLW 'payoutRatio'
# ABLLW 'fiveYearAvgDividendYield'
# ABLLW 'debtToEquity'
# ABLLW 'returnOnAssets'
# ABLLW 'returnOnEquity'
# ABLLW 'quickRatio'
# ABLLW 'currentRatio'
# ABNB 'dividendYield'
# ABNB 'fiveYearAvgDividendYield'
# ABOS 'overallRisk'
# ABOS 'trailingPE'
# ABOS 'earningsGrowth'
# ABOS 'revenueGrowth'
# ABOS 'dividendYield'
# ABOS 'fiveYearAvgDividendYield'
# ABSI 'trailingPE'
# ABSI 'earningsGrowth'
# ABSI 'dividendYield'
# ABSI 'fiveYearAvgDividendYield'
# ABUS 'trailingPE'
# ABUS 'pegRatio'
# ABUS 'earningsGrowth'
# ABUS 'dividendYield'
# ABUS 'fiveYearAvgDividendYield'
# ABVC 'overallRisk'
# ABVC 'trailingPE'
# ABVC 'pegRatio'
# ABVC 'earningsGrowth'
# ABVC 'dividendYield'
# ABVC 'fiveYearAvgDividendYield'
# AC 'recommendationMean'
# AC 'trailingPE'
# AC 'pegRatio'
# AC 'earningsGrowth'
# AC 'payoutRatio'
# AC 'debtToEquity'
# ACA 'fiveYearAvgDividendYield'
# ACABW 'sector'
# ACABW 'industry'
# ACABW 'recommendationMean'
# ACABW 'overallRisk'
# ACABW 'beta'
# ACABW 'trailingEps'
# ACABW 'forwardEps'
# ACABW 'trailingPE'
# ACABW 'forwardPE'
# ACABW 'pegRatio'
# ACABW 'bookValue'
# ACABW 'priceToBook'
# ACABW 'ebitdaMargins'
# ACABW 'profitMargins'
# ACABW 'earningsGrowth'
# ACABW 'revenueGrowth'
# ACABW 'dividendYield'
# ACABW 'payoutRatio'
# ACABW 'fiveYearAvgDividendYield'
# ACABW 'debtToEquity'
# ACABW 'returnOnAssets'
# ACABW 'returnOnEquity'
# ACABW 'quickRatio'
# ACABW 'currentRatio'
# ACAC 'recommendationMean'
# ACAC 'overallRisk'
# ACAC 'beta'
# ACAC 'forwardEps'
# ACAC 'forwardPE'
# ACAC 'pegRatio'
# ACAC 'priceToBook'
# ACAC 'earningsGrowth'
# ACAC 'revenueGrowth'
# ACAC 'dividendYield'
# ACAC 'fiveYearAvgDividendYield'
# ACAC 'debtToEquity'
# ACAC 'returnOnAssets'
# ACAC 'returnOnEquity'
# ACAD 'trailingPE'
# ACAD 'earningsGrowth'
# ACAD 'dividendYield'
# ACAD 'fiveYearAvgDividendYield'
# ACAH 'recommendationMean'
# ACAH 'overallRisk'
# ACAH 'forwardEps'
# ACAH 'forwardPE'
# ACAH 'pegRatio'
# ACAH 'priceToBook'
# ACAH 'revenueGrowth'
# ACAH 'dividendYield'
# ACAH 'fiveYearAvgDividendYield'
# ACAH 'debtToEquity'
# ACAH 'returnOnEquity'
# ACAHU 'recommendationMean'
# ACAHU 'overallRisk'
# ACAHU 'forwardEps'
# ACAHU 'trailingPE'
# ACAHU 'forwardPE'
# ACAHU 'pegRatio'
# ACAHU 'priceToBook'
# ACAHU 'revenueGrowth'
# ACAHU 'dividendYield'
# ACAHU 'payoutRatio'
# ACAHU 'fiveYearAvgDividendYield'
# ACAHU 'debtToEquity'
# ACAHU 'returnOnEquity'
# ACAHW 'sector'
# ACAHW 'industry'
# ACAHW 'recommendationMean'
# ACAHW 'overallRisk'
# ACAHW 'beta'
# ACAHW 'trailingEps'
# ACAHW 'forwardEps'
# ACAHW 'trailingPE'
# ACAHW 'forwardPE'
# ACAHW 'pegRatio'
# ACAHW 'bookValue'
# ACAHW 'priceToBook'
# ACAHW 'ebitdaMargins'
# ACAHW 'profitMargins'
# ACAHW 'earningsGrowth'
# ACAHW 'revenueGrowth'
# ACAHW 'dividendYield'
# ACAHW 'payoutRatio'
# ACAHW 'fiveYearAvgDividendYield'
# ACAHW 'debtToEquity'
# ACAHW 'returnOnAssets'
# ACAHW 'returnOnEquity'
# ACAHW 'quickRatio'
# ACAHW 'currentRatio'
# ACAQ 'recommendationMean'
# ACAQ 'overallRisk'
# ACAQ 'beta'
# ACAQ 'forwardEps'
# ACAQ 'forwardPE'
# ACAQ 'pegRatio'
# ACAQ 'priceToBook'
# ACAQ 'earningsGrowth'
# ACAQ 'revenueGrowth'
# ACAQ 'dividendYield'
# ACAQ 'fiveYearAvgDividendYield'
# ACAQ 'debtToEquity'
# ACAQ 'returnOnAssets'
# ACAQ 'returnOnEquity'
# ACB 'trailingPE'
# ACB 'pegRatio'
# ACB 'earningsGrowth'
# ACB 'dividendYield'
# ACB 'fiveYearAvgDividendYield'
# ACBA 'recommendationMean'
# ACBA 'overallRisk'
# ACBA 'forwardEps'
# ACBA 'forwardPE'
# ACBA 'pegRatio'
# ACBA 'priceToBook'
# ACBA 'earningsGrowth'
# ACBA 'revenueGrowth'
# ACBA 'dividendYield'
# ACBA 'fiveYearAvgDividendYield'
# ACBA 'debtToEquity'
# ACBA 'returnOnAssets'
# ACBA 'returnOnEquity'
# ACBAU 'recommendationMean'
# ACBAU 'overallRisk'
# ACBAU 'forwardEps'
# ACBAU 'trailingPE'
# ACBAU 'forwardPE'
# ACBAU 'pegRatio'
# ACBAU 'priceToBook'
# ACBAU 'earningsGrowth'
# ACBAU 'revenueGrowth'
# ACBAU 'dividendYield'
# ACBAU 'payoutRatio'
# ACBAU 'fiveYearAvgDividendYield'
# ACBAU 'debtToEquity'
# ACBAU 'returnOnAssets'
# ACBAU 'returnOnEquity'
# ACBAW 'sector'
# ACBAW 'industry'
# ACBAW 'recommendationMean'
# ACBAW 'overallRisk'
# ACBAW 'beta'
# ACBAW 'trailingEps'
# ACBAW 'forwardEps'
# ACBAW 'trailingPE'
# ACBAW 'forwardPE'
# ACBAW 'pegRatio'
# ACBAW 'bookValue'
# ACBAW 'priceToBook'
# ACBAW 'ebitdaMargins'
# ACBAW 'profitMargins'
# ACBAW 'earningsGrowth'
# ACBAW 'revenueGrowth'
# ACBAW 'dividendYield'
# ACBAW 'payoutRatio'
# ACBAW 'fiveYearAvgDividendYield'
# ACBAW 'debtToEquity'
# ACBAW 'returnOnAssets'
# ACBAW 'returnOnEquity'
# ACBAW 'quickRatio'
# ACBAW 'currentRatio'
# ACCD 'trailingPE'
# ACCD 'earningsGrowth'
# ACCD 'dividendYield'
# ACCD 'fiveYearAvgDividendYield'
# ACCO 'trailingPE'
# ACCO 'earningsGrowth'
# ACCO 'payoutRatio'
# ACDC 'beta'
# ACDC 'earningsGrowth'
# ACDC 'dividendYield'
# ACDC 'fiveYearAvgDividendYield'
# ACDCW 'sector'
# ACDCW 'industry'
# ACDCW 'recommendationMean'
# ACDCW 'overallRisk'
# ACDCW 'beta'
# ACDCW 'trailingEps'
# ACDCW 'forwardEps'
# ACDCW 'trailingPE'
# ACDCW 'forwardPE'
# ACDCW 'pegRatio'
# ACDCW 'bookValue'
# ACDCW 'priceToBook'
# ACDCW 'ebitdaMargins'
# ACDCW 'profitMargins'
# ACDCW 'earningsGrowth'
# ACDCW 'revenueGrowth'
# ACDCW 'dividendYield'
# ACDCW 'payoutRatio'
# ACDCW 'fiveYearAvgDividendYield'
# ACDCW 'debtToEquity'
# ACDCW 'returnOnAssets'
# ACDCW 'returnOnEquity'
# ACDCW 'quickRatio'
# ACDCW 'currentRatio'
# ACEL 'dividendYield'
# ACEL 'fiveYearAvgDividendYield'
# ACER 'overallRisk'
# ACER 'trailingPE'
# ACER 'pegRatio'
# ACER 'priceToBook'
# ACER 'earningsGrowth'
# ACER 'revenueGrowth'
# ACER 'dividendYield'
# ACER 'fiveYearAvgDividendYield'
# ACER 'debtToEquity'
# ACER 'returnOnEquity'
# ACET 'trailingPE'
# ACET 'earningsGrowth'
# ACET 'revenueGrowth'
# ACET 'dividendYield'
# ACET 'fiveYearAvgDividendYield'
# ACGL 'dividendYield'
# ACGL 'fiveYearAvgDividendYield'
# ACGLN 'recommendationMean'
# ACGLN 'forwardEps'
# ACGLN 'forwardPE'
# ACGLN 'pegRatio'
# ACGLN 'payoutRatio'
# ACGLN 'fiveYearAvgDividendYield'
# ACGLO 'recommendationMean'
# ACGLO 'forwardEps'
# ACGLO 'forwardPE'
# ACGLO 'pegRatio'
# ACGLO 'payoutRatio'
# ACGN 'trailingPE'
# ACGN 'pegRatio'
# ACGN 'earningsGrowth'
# ACGN 'revenueGrowth'
# ACGN 'dividendYield'
# ACGN 'fiveYearAvgDividendYield'
# ACHC 'dividendYield'
# ACHC 'fiveYearAvgDividendYield'
# ACHL 'overallRisk'
# ACHL 'beta'
# ACHL 'trailingPE'
# ACHL 'earningsGrowth'
# ACHL 'revenueGrowth'
# ACHL 'dividendYield'
# ACHL 'fiveYearAvgDividendYield'
# ACHR 'trailingPE'
# ACHR 'pegRatio'
# ACHR 'earningsGrowth'
# ACHR 'revenueGrowth'
# ACHR 'dividendYield'
# ACHR 'fiveYearAvgDividendYield'
# ACHV 'overallRisk'
# ACHV 'trailingPE'
# ACHV 'earningsGrowth'
# ACHV 'revenueGrowth'
# ACHV 'dividendYield'
# ACHV 'fiveYearAvgDividendYield'
# ACI 'fiveYearAvgDividendYield'
# ACIU 'overallRisk'
# ACIU 'trailingPE'
# ACIU 'pegRatio'
# ACIU 'earningsGrowth'
# ACIU 'revenueGrowth'
# ACIU 'dividendYield'
# ACIU 'fiveYearAvgDividendYield'
# ACIW 'earningsGrowth'
# ACIW 'dividendYield'
# ACIW 'fiveYearAvgDividendYield'
# ACLS 'dividendYield'
# ACLS 'fiveYearAvgDividendYield'
# ACLX 'beta'
# ACLX 'trailingPE'
# ACLX 'earningsGrowth'
# ACLX 'revenueGrowth'
# ACLX 'dividendYield'
# ACLX 'fiveYearAvgDividendYield'
# ACM 'fiveYearAvgDividendYield'
# ACMR 'dividendYield'
# ACMR 'fiveYearAvgDividendYield'
# ACNB 'pegRatio'
# ACNB 'debtToEquity'
# ACNB 'quickRatio'
# ACNB 'currentRatio'
# ACNT 'overallRisk'
# ACNT 'earningsGrowth'
# ACNT 'dividendYield'
# ACNT 'fiveYearAvgDividendYield'
# ACON 'overallRisk'
# ACON 'beta'
# ACON 'trailingPE'
# ACON 'pegRatio'
# ACON 'earningsGrowth'
# ACON 'dividendYield'
# ACON 'fiveYearAvgDividendYield'
# ACON 'debtToEquity'
# ACON 'returnOnEquity'
# ACONW 'shortName'
# ACONW 'sector'
# ACONW 'industry'
# ACONW 'recommendationMean'
# ACONW 'overallRisk'
# ACONW 'beta'
# ACONW 'trailingEps'
# ACONW 'forwardEps'
# ACONW 'trailingPE'
# ACONW 'forwardPE'
# ACONW 'pegRatio'
# ACONW 'bookValue'
# ACONW 'priceToBook'
# ACONW 'ebitdaMargins'
# ACONW 'profitMargins'
# ACONW 'earningsGrowth'
# ACONW 'revenueGrowth'
# ACONW 'dividendYield'
# ACONW 'payoutRatio'
# ACONW 'fiveYearAvgDividendYield'
# ACONW 'debtToEquity'
# ACONW 'returnOnAssets'
# ACONW 'returnOnEquity'
# ACONW 'quickRatio'
# ACONW 'currentRatio'
# ACOR 'trailingPE'
# ACOR 'pegRatio'
# ACOR 'earningsGrowth'
# ACOR 'dividendYield'
# ACOR 'fiveYearAvgDividendYield'
# ACP 'recommendationMean'
# ACP 'overallRisk'
# ACP 'forwardEps'
# ACP 'trailingPE'
# ACP 'forwardPE'
# ACP 'pegRatio'
# ACP 'earningsGrowth'
# ACP 'payoutRatio'
# ACR 'trailingPE'
# ACR 'dividendYield'
# ACR 'fiveYearAvgDividendYield'
# ACRE 'earningsGrowth'
# ACRE 'payoutRatio'
# ACRO 'recommendationMean'
# ACRO 'overallRisk'
# ACRO 'beta'
# ACRO 'forwardEps'
# ACRO 'forwardPE'
# ACRO 'pegRatio'
# ACRO 'priceToBook'
# ACRO 'earningsGrowth'
# ACRO 'revenueGrowth'
# ACRO 'dividendYield'
# ACRO 'fiveYearAvgDividendYield'
# ACRO 'debtToEquity'
# ACRO 'returnOnEquity'
# ACRS 'trailingPE'
# ACRS 'earningsGrowth'
# ACRS 'dividendYield'
# ACRS 'fiveYearAvgDividendYield'
# ACRV 'beta'
# ACRV 'trailingPE'
# ACRV 'pegRatio'
# ACRV 'earningsGrowth'
# ACRV 'revenueGrowth'
# ACRV 'dividendYield'
# ACRV 'fiveYearAvgDividendYield'
# ACRV 'returnOnAssets'
# ACRX 'overallRisk'
# ACRX 'pegRatio'
# ACRX 'earningsGrowth'
# ACRX 'revenueGrowth'
# ACRX 'dividendYield'
# ACRX 'fiveYearAvgDividendYield'
# ACRX 'returnOnEquity'
# ACST 'overallRisk'
# ACST 'trailingPE'
# ACST 'pegRatio'
# ACST 'earningsGrowth'
# ACST 'revenueGrowth'
# ACST 'dividendYield'
# ACST 'fiveYearAvgDividendYield'
# ACT 'beta'
# ACT 'fiveYearAvgDividendYield'
# ACTG 'recommendationMean'
# ACTG 'trailingPE'
# ACTG 'pegRatio'
# ACTG 'earningsGrowth'
# ACTG 'dividendYield'
# ACTG 'fiveYearAvgDividendYield'
# ACU 'overallRisk'
# ACV 'overallRisk'
# ACV 'beta'
# ACV 'forwardEps'
# ACV 'trailingPE'
# ACV 'forwardPE'
# ACV 'pegRatio'
# ACV 'bookValue'
# ACV 'priceToBook'
# ACV 'earningsGrowth'
# ACV 'revenueGrowth'
# ACV 'payoutRatio'
# ACV 'debtToEquity'
# ACV 'returnOnAssets'
# ACV 'returnOnEquity'
# ACV 'quickRatio'
# ACV 'currentRatio'
# ACVA 'trailingPE'
# ACVA 'earningsGrowth'
# ACVA 'dividendYield'
# ACVA 'fiveYearAvgDividendYield'
# ACXP 'overallRisk'
# ACXP 'trailingPE'
# ACXP 'pegRatio'
# ACXP 'earningsGrowth'
# ACXP 'revenueGrowth'
# ACXP 'dividendYield'
# ACXP 'fiveYearAvgDividendYield'
# ACXP 'debtToEquity'
# ADAG 'overallRisk'
# ADAG 'trailingPE'
# ADAG 'pegRatio'
# ADAG 'earningsGrowth'
# ADAG 'dividendYield'
# ADAG 'fiveYearAvgDividendYield'
# ADAP 'overallRisk'
# ADAP 'trailingPE'
# ADAP 'earningsGrowth'
# ADAP 'dividendYield'
# ADAP 'fiveYearAvgDividendYield'
# ADBE 'dividendYield'
# ADBE 'fiveYearAvgDividendYield'
# ADCT 'overallRisk'
# ADCT 'trailingPE'
# ADCT 'earningsGrowth'
# ADCT 'dividendYield'
# ADCT 'fiveYearAvgDividendYield'
# ADD 'recommendationMean'
# ADD 'overallRisk'
# ADD 'forwardEps'
# ADD 'trailingPE'
# ADD 'forwardPE'
# ADD 'pegRatio'
# ADD 'earningsGrowth'
# ADD 'revenueGrowth'
# ADD 'dividendYield'
# ADD 'fiveYearAvgDividendYield'
# ADER 'recommendationMean'
# ADER 'overallRisk'
# ADER 'forwardEps'
# ADER 'forwardPE'
# ADER 'pegRatio'
# ADER 'priceToBook'
# ADER 'earningsGrowth'
# ADER 'revenueGrowth'
# ADER 'dividendYield'
# ADER 'fiveYearAvgDividendYield'
# ADER 'debtToEquity'
# ADER 'returnOnEquity'
# ADERW 'sector'
# ADERW 'industry'
# ADERW 'recommendationMean'
# ADERW 'overallRisk'
# ADERW 'beta'
# ADERW 'trailingEps'
# ADERW 'forwardEps'
# ADERW 'trailingPE'
# ADERW 'forwardPE'
# ADERW 'pegRatio'
# ADERW 'bookValue'
# ADERW 'priceToBook'
# ADERW 'ebitdaMargins'
# ADERW 'profitMargins'
# ADERW 'earningsGrowth'
# ADERW 'revenueGrowth'
# ADERW 'dividendYield'
# ADERW 'payoutRatio'
# ADERW 'fiveYearAvgDividendYield'
# ADERW 'debtToEquity'
# ADERW 'returnOnAssets'
# ADERW 'returnOnEquity'
# ADERW 'quickRatio'
# ADERW 'currentRatio'
# ADES 'beta'
# ADES 'trailingPE'
# ADES 'earningsGrowth'
# ADES 'dividendYield'
# ADES 'fiveYearAvgDividendYield'
# ADES 'returnOnAssets'
# ADES 'returnOnEquity'
# ADEX 'recommendationMean'
# ADEX 'overallRisk'
# ADEX 'forwardEps'
# ADEX 'forwardPE'
# ADEX 'pegRatio'
# ADEX 'priceToBook'
# ADEX 'earningsGrowth'
# ADEX 'revenueGrowth'
# ADEX 'dividendYield'
# ADEX 'payoutRatio'
# ADEX 'fiveYearAvgDividendYield'
# ADEX 'debtToEquity'
# ADEX 'returnOnEquity'
# ADIL 'overallRisk'
# ADIL 'trailingPE'
# ADIL 'pegRatio'
# ADIL 'earningsGrowth'
# ADIL 'revenueGrowth'
# ADIL 'dividendYield'
# ADIL 'fiveYearAvgDividendYield'
# ADMA 'trailingPE'
# ADMA 'pegRatio'
# ADMA 'earningsGrowth'
# ADMA 'dividendYield'
# ADMA 'fiveYearAvgDividendYield'
# ADMP 'overallRisk'
# ADMP 'trailingPE'
# ADMP 'pegRatio'
# ADMP 'priceToBook'
# ADMP 'earningsGrowth'
# ADMP 'dividendYield'
# ADMP 'fiveYearAvgDividendYield'
# ADMP 'debtToEquity'
# ADN 'overallRisk'
# ADN 'trailingPE'
# ADN 'pegRatio'
# ADN 'earningsGrowth'
# ADN 'dividendYield'
# ADN 'fiveYearAvgDividendYield'
# ADNT 'earningsGrowth'
# ADNT 'dividendYield'
# ADNT 'fiveYearAvgDividendYield'
# ADNWW 'sector'
# ADNWW 'industry'
# ADNWW 'recommendationMean'
# ADNWW 'overallRisk'
# ADNWW 'beta'
# ADNWW 'trailingEps'
# ADNWW 'forwardEps'
# ADNWW 'trailingPE'
# ADNWW 'forwardPE'
# ADNWW 'pegRatio'
# ADNWW 'bookValue'
# ADNWW 'priceToBook'
# ADNWW 'ebitdaMargins'
# ADNWW 'profitMargins'
# ADNWW 'earningsGrowth'
# ADNWW 'revenueGrowth'
# ADNWW 'dividendYield'
# ADNWW 'payoutRatio'
# ADNWW 'fiveYearAvgDividendYield'
# ADNWW 'debtToEquity'
# ADNWW 'returnOnAssets'
# ADNWW 'returnOnEquity'
# ADNWW 'quickRatio'
# ADNWW 'currentRatio'
# ADOC 'recommendationMean'
# ADOC 'overallRisk'
# ADOC 'forwardEps'
# ADOC 'trailingPE'
# ADOC 'forwardPE'
# ADOC 'pegRatio'
# ADOC 'priceToBook'
# ADOC 'earningsGrowth'
# ADOC 'revenueGrowth'
# ADOC 'dividendYield'
# ADOC 'fiveYearAvgDividendYield'
# ADOC 'debtToEquity'
# ADOC 'returnOnEquity'
# ADOCR 'sector'
# ADOCR 'industry'
# ADOCR 'recommendationMean'
# ADOCR 'overallRisk'
# ADOCR 'forwardEps'
# ADOCR 'trailingPE'
# ADOCR 'forwardPE'
# ADOCR 'pegRatio'
# ADOCR 'priceToBook'
# ADOCR 'earningsGrowth'
# ADOCR 'revenueGrowth'
# ADOCR 'dividendYield'
# ADOCR 'payoutRatio'
# ADOCR 'fiveYearAvgDividendYield'
# ADOCR 'debtToEquity'
# ADOCR 'returnOnEquity'
# ADOCW 'sector'
# ADOCW 'industry'
# ADOCW 'recommendationMean'
# ADOCW 'overallRisk'
# ADOCW 'beta'
# ADOCW 'trailingEps'
# ADOCW 'forwardEps'
# ADOCW 'trailingPE'
# ADOCW 'forwardPE'
# ADOCW 'pegRatio'
# ADOCW 'bookValue'
# ADOCW 'priceToBook'
# ADOCW 'ebitdaMargins'
# ADOCW 'profitMargins'
# ADOCW 'earningsGrowth'
# ADOCW 'revenueGrowth'
# ADOCW 'dividendYield'
# ADOCW 'payoutRatio'
# ADOCW 'fiveYearAvgDividendYield'
# ADOCW 'debtToEquity'
# ADOCW 'returnOnAssets'
# ADOCW 'returnOnEquity'
# ADOCW 'quickRatio'
# ADOCW 'currentRatio'
# ADPT 'trailingPE'
# ADPT 'earningsGrowth'
# ADPT 'dividendYield'
# ADPT 'fiveYearAvgDividendYield'
# ADRT 'recommendationMean'
# ADRT 'overallRisk'
# ADRT 'beta'
# ADRT 'forwardEps'
# ADRT 'forwardPE'
# ADRT 'pegRatio'
# ADRT 'priceToBook'
# ADRT 'earningsGrowth'
# ADRT 'revenueGrowth'
# ADRT 'dividendYield'
# ADRT 'fiveYearAvgDividendYield'
# ADRT 'debtToEquity'
# ADRT 'returnOnEquity'
# ADSE 'overallRisk'
# ADSE 'trailingPE'
# ADSE 'pegRatio'
# ADSE 'earningsGrowth'
# ADSE 'dividendYield'
# ADSE 'fiveYearAvgDividendYield'
# ADSEW 'sector'
# ADSEW 'industry'
# ADSEW 'recommendationMean'
# ADSEW 'overallRisk'
# ADSEW 'beta'
# ADSEW 'trailingEps'
# ADSEW 'forwardEps'
# ADSEW 'trailingPE'
# ADSEW 'forwardPE'
# ADSEW 'pegRatio'
# ADSEW 'bookValue'
# ADSEW 'priceToBook'
# ADSEW 'ebitdaMargins'
# ADSEW 'profitMargins'
# ADSEW 'earningsGrowth'
# ADSEW 'revenueGrowth'
# ADSEW 'dividendYield'
# ADSEW 'payoutRatio'
# ADSEW 'fiveYearAvgDividendYield'
# ADSEW 'debtToEquity'
# ADSEW 'returnOnAssets'
# ADSEW 'returnOnEquity'
# ADSEW 'quickRatio'
# ADSEW 'currentRatio'
# ADSK 'dividendYield'
# ADSK 'fiveYearAvgDividendYield'
# ADT 'beta'
# ADT 'earningsGrowth'
# ADT 'revenueGrowth'
# ADT 'debtToEquity'
# ADT 'returnOnAssets'
# ADT 'returnOnEquity'
# ADT 'quickRatio'
# ADT 'currentRatio'
# ADTH 'dividendYield'
# ADTH 'fiveYearAvgDividendYield'
# ADTHW 'shortName'
# ADTHW 'sector'
# ADTHW 'industry'
# ADTHW 'recommendationMean'
# ADTHW 'overallRisk'
# ADTHW 'beta'
# ADTHW 'trailingEps'
# ADTHW 'forwardEps'
# ADTHW 'forwardPE'
# ADTHW 'pegRatio'
# ADTHW 'bookValue'
# ADTHW 'priceToBook'
# ADTHW 'ebitdaMargins'
# ADTHW 'profitMargins'
# ADTHW 'earningsGrowth'
# ADTHW 'revenueGrowth'
# ADTHW 'dividendYield'
# ADTHW 'payoutRatio'
# ADTHW 'fiveYearAvgDividendYield'
# ADTHW 'debtToEquity'
# ADTHW 'returnOnAssets'
# ADTHW 'returnOnEquity'
# ADTHW 'quickRatio'
# ADTHW 'currentRatio'
# ADTN 'trailingPE'
# ADTN 'earningsGrowth'
# ADTN 'payoutRatio'
# ADTX 'overallRisk'
# ADTX 'trailingPE'
# ADTX 'pegRatio'
# ADTX 'earningsGrowth'
# ADTX 'dividendYield'
# ADTX 'fiveYearAvgDividendYield'
# ADUS 'dividendYield'
# ADUS 'fiveYearAvgDividendYield'
# ADV 'trailingPE'
# ADV 'earningsGrowth'
# ADV 'dividendYield'
# ADV 'fiveYearAvgDividendYield'
# ADVM 'trailingPE'
# ADVM 'pegRatio'
# ADVM 'earningsGrowth'
# ADVM 'revenueGrowth'
# ADVM 'dividendYield'
# ADVM 'fiveYearAvgDividendYield'
# ADVWW 'sector'
# ADVWW 'industry'
# ADVWW 'recommendationMean'
# ADVWW 'overallRisk'
# ADVWW 'beta'
# ADVWW 'trailingEps'
# ADVWW 'forwardEps'
# ADVWW 'trailingPE'
# ADVWW 'forwardPE'
# ADVWW 'pegRatio'
# ADVWW 'bookValue'
# ADVWW 'priceToBook'
# ADVWW 'ebitdaMargins'
# ADVWW 'profitMargins'
# ADVWW 'earningsGrowth'
# ADVWW 'revenueGrowth'
# ADVWW 'dividendYield'
# ADVWW 'payoutRatio'
# ADVWW 'fiveYearAvgDividendYield'
# ADVWW 'debtToEquity'
# ADVWW 'returnOnAssets'
# ADVWW 'returnOnEquity'
# ADVWW 'quickRatio'
# ADVWW 'currentRatio'
# ADX 'recommendationMean'
# ADX 'overallRisk'
# ADX 'forwardEps'
# ADX 'trailingPE'
# ADX 'forwardPE'
# ADX 'pegRatio'
# ADX 'payoutRatio'
# ADX 'debtToEquity'
# ADXN 'recommendationMean'
# ADXN 'overallRisk'
# ADXN 'forwardEps'
# ADXN 'trailingPE'
# ADXN 'forwardPE'
# ADXN 'pegRatio'
# ADXN 'earningsGrowth'
# ADXN 'dividendYield'
# ADXN 'fiveYearAvgDividendYield'
# AE 'overallRisk'
# AE 'trailingPE'
# AE 'pegRatio'
# AE 'earningsGrowth'
# AE 'payoutRatio'
# AEAE 'recommendationMean'
# AEAE 'overallRisk'
# AEAE 'beta'
# AEAE 'forwardEps'
# AEAE 'forwardPE'
# AEAE 'pegRatio'
# AEAE 'priceToBook'
# AEAE 'revenueGrowth'
# AEAE 'dividendYield'
# AEAE 'fiveYearAvgDividendYield'
# AEAE 'debtToEquity'
# AEAE 'returnOnEquity'
# AEAEU 'recommendationMean'
# AEAEU 'overallRisk'
# AEAEU 'beta'
# AEAEU 'forwardEps'
# AEAEU 'forwardPE'
# AEAEU 'pegRatio'
# AEAEU 'priceToBook'
# AEAEU 'revenueGrowth'
# AEAEU 'dividendYield'
# AEAEU 'payoutRatio'
# AEAEU 'fiveYearAvgDividendYield'
# AEAEU 'debtToEquity'
# AEAEU 'returnOnEquity'
# AEAEW 'sector'
# AEAEW 'industry'
# AEAEW 'recommendationMean'
# AEAEW 'overallRisk'
# AEAEW 'beta'
# AEAEW 'trailingEps'
# AEAEW 'forwardEps'
# AEAEW 'trailingPE'
# AEAEW 'forwardPE'
# AEAEW 'pegRatio'
# AEAEW 'bookValue'
# AEAEW 'priceToBook'
# AEAEW 'ebitdaMargins'
# AEAEW 'profitMargins'
# AEAEW 'earningsGrowth'
# AEAEW 'revenueGrowth'
# AEAEW 'dividendYield'
# AEAEW 'payoutRatio'
# AEAEW 'fiveYearAvgDividendYield'
# AEAEW 'debtToEquity'
# AEAEW 'returnOnAssets'
# AEAEW 'returnOnEquity'
# AEAEW 'quickRatio'
# AEAEW 'currentRatio'
# AEF 'recommendationMean'
# AEF 'overallRisk'
# AEF 'forwardEps'
# AEF 'trailingPE'
# AEF 'forwardPE'
# AEF 'pegRatio'
# AEF 'earningsGrowth'
# AEF 'payoutRatio'
# AEFC 'sector'
# AEFC 'industry'
# AEFC 'recommendationMean'
# AEFC 'overallRisk'
# AEFC 'beta'
# AEFC 'trailingEps'
# AEFC 'forwardEps'
# AEFC 'trailingPE'
# AEFC 'forwardPE'
# AEFC 'pegRatio'
# AEFC 'bookValue'
# AEFC 'priceToBook'
# AEFC 'ebitdaMargins'
# AEFC 'profitMargins'
# AEFC 'earningsGrowth'
# AEFC 'revenueGrowth'
# AEFC 'dividendYield'
# AEFC 'payoutRatio'
# AEFC 'fiveYearAvgDividendYield'
# AEFC 'debtToEquity'
# AEFC 'returnOnAssets'
# AEFC 'returnOnEquity'
# AEFC 'quickRatio'
# AEFC 'currentRatio'
# AEG 'trailingPE'
# AEG 'earningsGrowth'
# AEG 'revenueGrowth'
# AEG 'payoutRatio'
# AEHL 'recommendationMean'
# AEHL 'overallRisk'
# AEHL 'forwardEps'
# AEHL 'trailingPE'
# AEHL 'forwardPE'
# AEHL 'pegRatio'
# AEHL 'earningsGrowth'
# AEHL 'revenueGrowth'
# AEHL 'dividendYield'
# AEHL 'fiveYearAvgDividendYield'
# AEHR 'overallRisk'
# AEHR 'dividendYield'
# AEHR 'fiveYearAvgDividendYield'
# AEI 'forwardEps'
# AEI 'trailingPE'
# AEI 'forwardPE'
# AEI 'pegRatio'
# AEI 'earningsGrowth'
# AEI 'dividendYield'
# AEI 'fiveYearAvgDividendYield'
# AEIS 'fiveYearAvgDividendYield'
# AEL 'earningsGrowth'
# AEL 'dividendYield'
# AEMD 'overallRisk'
# AEMD 'trailingPE'
# AEMD 'pegRatio'
# AEMD 'earningsGrowth'
# AEMD 'dividendYield'
# AEMD 'fiveYearAvgDividendYield'
# AENT 'recommendationMean'
# AENT 'overallRisk'
# AENT 'forwardEps'
# AENT 'forwardPE'
# AENT 'pegRatio'
# AENT 'earningsGrowth'
# AENT 'dividendYield'
# AENT 'fiveYearAvgDividendYield'
# AENTW 'recommendationMean'
# AENTW 'overallRisk'
# AENTW 'trailingEps'
# AENTW 'forwardEps'
# AENTW 'trailingPE'
# AENTW 'forwardPE'
# AENTW 'pegRatio'
# AENTW 'earningsGrowth'
# AENTW 'dividendYield'
# AENTW 'payoutRatio'
# AENTW 'fiveYearAvgDividendYield'
# AENZ 'overallRisk'
# AENZ 'forwardEps'
# AENZ 'trailingPE'
# AENZ 'forwardPE'
# AENZ 'pegRatio'
# AENZ 'earningsGrowth'
# AENZ 'dividendYield'
# AENZ 'fiveYearAvgDividendYield'
# AEON 'recommendationMean'
# AEON 'overallRisk'
# AEON 'forwardEps'
# AEON 'trailingPE'
# AEON 'forwardPE'
# AEON 'pegRatio'
# AEON 'priceToBook'
# AEON 'earningsGrowth'
# AEON 'revenueGrowth'
# AEON 'dividendYield'
# AEON 'fiveYearAvgDividendYield'
# AEON 'debtToEquity'
# AEON 'returnOnEquity'
# AEPPZ 'recommendationMean'
# AEPPZ 'forwardEps'
# AEPPZ 'forwardPE'
# AEPPZ 'pegRatio'
# AEPPZ 'dividendYield'
# AEPPZ 'payoutRatio'
# AEPPZ 'fiveYearAvgDividendYield'
# AER 'dividendYield'
# AER 'fiveYearAvgDividendYield'
# AES 'trailingPE'
# AES 'earningsGrowth'
# AES 'payoutRatio'
# AESC 'recommendationMean'
# AESC 'forwardEps'
# AESC 'trailingPE'
# AESC 'forwardPE'
# AESC 'pegRatio'
# AESC 'earningsGrowth'
# AESC 'dividendYield'
# AESC 'payoutRatio'
# AESC 'fiveYearAvgDividendYield'
# AESI 'overallRisk'
# AESI 'beta'
# AESI 'fiveYearAvgDividendYield'
# AEVA 'trailingPE'
# AEVA 'earningsGrowth'
# AEVA 'dividendYield'
# AEVA 'fiveYearAvgDividendYield'
# AEY 'recommendationMean'
# AEY 'overallRisk'
# AEY 'forwardEps'
# AEY 'trailingPE'
# AEY 'forwardPE'
# AEY 'pegRatio'
# AEY 'earningsGrowth'
# AEY 'dividendYield'
# AEY 'fiveYearAvgDividendYield'
# AEY 'returnOnAssets'
# AEY 'returnOnEquity'
# AEYE 'overallRisk'
# AEYE 'trailingPE'
# AEYE 'pegRatio'
# AEYE 'earningsGrowth'
# AEYE 'dividendYield'
# AEYE 'fiveYearAvgDividendYield'
# AEZS 'recommendationMean'
# AEZS 'overallRisk'
# AEZS 'trailingPE'
# AEZS 'pegRatio'
# AEZS 'earningsGrowth'
# AEZS 'dividendYield'
# AEZS 'fiveYearAvgDividendYield'
# AFAR 'recommendationMean'
# AFAR 'overallRisk'
# AFAR 'beta'
# AFAR 'forwardEps'
# AFAR 'forwardPE'
# AFAR 'pegRatio'
# AFAR 'priceToBook'
# AFAR 'earningsGrowth'
# AFAR 'revenueGrowth'
# AFAR 'dividendYield'
# AFAR 'fiveYearAvgDividendYield'
# AFAR 'debtToEquity'
# AFAR 'returnOnAssets'
# AFAR 'returnOnEquity'
# AFARU 'recommendationMean'
# AFARU 'overallRisk'
# AFARU 'beta'
# AFARU 'trailingEps'
# AFARU 'forwardEps'
# AFARU 'trailingPE'
# AFARU 'forwardPE'
# AFARU 'pegRatio'
# AFARU 'priceToBook'
# AFARU 'earningsGrowth'
# AFARU 'revenueGrowth'
# AFARU 'dividendYield'
# AFARU 'payoutRatio'
# AFARU 'fiveYearAvgDividendYield'
# AFARU 'debtToEquity'
# AFARU 'returnOnAssets'
# AFARU 'returnOnEquity'
# AFB 'recommendationMean'
# AFB 'overallRisk'
# AFB 'forwardEps'
# AFB 'trailingPE'
# AFB 'forwardPE'
# AFB 'pegRatio'
# AFB 'earningsGrowth'
# AFB 'payoutRatio'
# AFBI 'recommendationMean'
# AFBI 'overallRisk'
# AFBI 'forwardEps'
# AFBI 'forwardPE'
# AFBI 'pegRatio'
# AFBI 'dividendYield'
# AFBI 'fiveYearAvgDividendYield'
# AFBI 'debtToEquity'
# AFBI 'quickRatio'
# AFBI 'currentRatio'
# AFCG 'pegRatio'
# AFCG 'fiveYearAvgDividendYield'
# AFGB 'sector'
# AFGB 'industry'
# AFGB 'recommendationMean'
# AFGB 'overallRisk'
# AFGB 'beta'
# AFGB 'trailingEps'
# AFGB 'forwardEps'
# AFGB 'trailingPE'
# AFGB 'forwardPE'
# AFGB 'pegRatio'
# AFGB 'bookValue'
# AFGB 'priceToBook'
# AFGB 'ebitdaMargins'
# AFGB 'profitMargins'
# AFGB 'earningsGrowth'
# AFGB 'revenueGrowth'
# AFGB 'dividendYield'
# AFGB 'payoutRatio'
# AFGB 'fiveYearAvgDividendYield'
# AFGB 'debtToEquity'
# AFGB 'returnOnAssets'
# AFGB 'returnOnEquity'
# AFGB 'quickRatio'
# AFGB 'currentRatio'
# AFGC 'sector'
# AFGC 'industry'
# AFGC 'recommendationMean'
# AFGC 'overallRisk'
# AFGC 'beta'
# AFGC 'trailingEps'
# AFGC 'forwardEps'
# AFGC 'trailingPE'
# AFGC 'forwardPE'
# AFGC 'pegRatio'
# AFGC 'bookValue'
# AFGC 'priceToBook'
# AFGC 'ebitdaMargins'
# AFGC 'profitMargins'
# AFGC 'earningsGrowth'
# AFGC 'revenueGrowth'
# AFGC 'dividendYield'
# AFGC 'payoutRatio'
# AFGC 'fiveYearAvgDividendYield'
# AFGC 'debtToEquity'
# AFGC 'returnOnAssets'
# AFGC 'returnOnEquity'
# AFGC 'quickRatio'
# AFGC 'currentRatio'
# AFGD 'sector'
# AFGD 'industry'
# AFGD 'recommendationMean'
# AFGD 'overallRisk'
# AFGD 'beta'
# AFGD 'trailingEps'
# AFGD 'forwardEps'
# AFGD 'trailingPE'
# AFGD 'forwardPE'
# AFGD 'pegRatio'
# AFGD 'bookValue'
# AFGD 'priceToBook'
# AFGD 'ebitdaMargins'
# AFGD 'profitMargins'
# AFGD 'earningsGrowth'
# AFGD 'revenueGrowth'
# AFGD 'dividendYield'
# AFGD 'payoutRatio'
# AFGD 'fiveYearAvgDividendYield'
# AFGD 'debtToEquity'
# AFGD 'returnOnAssets'
# AFGD 'returnOnEquity'
# AFGD 'quickRatio'
# AFGD 'currentRatio'
# AFGE 'sector'
# AFGE 'industry'
# AFGE 'recommendationMean'
# AFGE 'overallRisk'
# AFGE 'beta'
# AFGE 'trailingEps'
# AFGE 'forwardEps'
# AFGE 'trailingPE'
# AFGE 'forwardPE'
# AFGE 'pegRatio'
# AFGE 'bookValue'
# AFGE 'priceToBook'
# AFGE 'ebitdaMargins'
# AFGE 'profitMargins'
# AFGE 'earningsGrowth'
# AFGE 'revenueGrowth'
# AFGE 'dividendYield'
# AFGE 'payoutRatio'
# AFGE 'fiveYearAvgDividendYield'
# AFGE 'debtToEquity'
# AFGE 'returnOnAssets'
# AFGE 'returnOnEquity'
# AFGE 'quickRatio'
# AFGE 'currentRatio'
# AFIB 'overallRisk'
# AFIB 'trailingPE'
# AFIB 'pegRatio'
# AFIB 'earningsGrowth'
# AFIB 'dividendYield'
# AFIB 'fiveYearAvgDividendYield'
# AFMD 'trailingPE'
# AFMD 'pegRatio'
# AFMD 'earningsGrowth'
# AFMD 'dividendYield'
# AFMD 'fiveYearAvgDividendYield'
# AFRI 'recommendationMean'
# AFRI 'overallRisk'
# AFRI 'forwardEps'
# AFRI 'trailingPE'
# AFRI 'forwardPE'
# AFRI 'pegRatio'
# AFRI 'earningsGrowth'
# AFRI 'dividendYield'
# AFRI 'fiveYearAvgDividendYield'
# AFRIW 'sector'
# AFRIW 'industry'
# AFRIW 'recommendationMean'
# AFRIW 'overallRisk'
# AFRIW 'beta'
# AFRIW 'trailingEps'
# AFRIW 'forwardEps'
# AFRIW 'trailingPE'
# AFRIW 'forwardPE'
# AFRIW 'pegRatio'
# AFRIW 'bookValue'
# AFRIW 'priceToBook'
# AFRIW 'ebitdaMargins'
# AFRIW 'profitMargins'
# AFRIW 'earningsGrowth'
# AFRIW 'revenueGrowth'
# AFRIW 'dividendYield'
# AFRIW 'payoutRatio'
# AFRIW 'fiveYearAvgDividendYield'
# AFRIW 'debtToEquity'
# AFRIW 'returnOnAssets'
# AFRIW 'returnOnEquity'
# AFRIW 'quickRatio'
# AFRIW 'currentRatio'
# AFRM 'trailingPE'
# AFRM 'earningsGrowth'
# AFRM 'dividendYield'
# AFRM 'fiveYearAvgDividendYield'
# AFT 'overallRisk'
# AFT 'forwardEps'
# AFT 'trailingPE'
# AFT 'forwardPE'
# AFT 'pegRatio'
# AFT 'payoutRatio'
# AFTR 'recommendationMean'
# AFTR 'overallRisk'
# AFTR 'beta'
# AFTR 'forwardEps'
# AFTR 'forwardPE'
# AFTR 'pegRatio'
# AFTR 'priceToBook'
# AFTR 'revenueGrowth'
# AFTR 'dividendYield'
# AFTR 'fiveYearAvgDividendYield'
# AFTR 'debtToEquity'
# AFTR 'returnOnAssets'
# AFTR 'returnOnEquity'
# AFYA 'overallRisk'
# AFYA 'dividendYield'
# AFYA 'fiveYearAvgDividendYield'
# AG 'trailingPE'
# AG 'earningsGrowth'
# AG 'payoutRatio'
# AG 'fiveYearAvgDividendYield'
# AGAC 'recommendationMean'
# AGAC 'overallRisk'
# AGAC 'forwardEps'
# AGAC 'trailingPE'
# AGAC 'forwardPE'
# AGAC 'pegRatio'
# AGAC 'priceToBook'
# AGAC 'revenueGrowth'
# AGAC 'dividendYield'
# AGAC 'fiveYearAvgDividendYield'
# AGAC 'debtToEquity'
# AGAC 'returnOnAssets'
# AGAC 'returnOnEquity'
# AGAE 'overallRisk'
# AGAE 'forwardEps'
# AGAE 'trailingPE'
# AGAE 'forwardPE'
# AGAE 'pegRatio'
# AGAE 'earningsGrowth'
# AGAE 'dividendYield'
# AGAE 'fiveYearAvgDividendYield'
# AGBA 'recommendationMean'
# AGBA 'overallRisk'
# AGBA 'forwardEps'
# AGBA 'trailingPE'
# AGBA 'forwardPE'
# AGBA 'pegRatio'
# AGBA 'earningsGrowth'
# AGBA 'dividendYield'
# AGBA 'fiveYearAvgDividendYield'
# AGBAW 'sector'
# AGBAW 'industry'
# AGBAW 'recommendationMean'
# AGBAW 'overallRisk'
# AGBAW 'beta'
# AGBAW 'trailingEps'
# AGBAW 'forwardEps'
# AGBAW 'trailingPE'
# AGBAW 'forwardPE'
# AGBAW 'pegRatio'
# AGBAW 'bookValue'
# AGBAW 'priceToBook'
# AGBAW 'ebitdaMargins'
# AGBAW 'profitMargins'
# AGBAW 'earningsGrowth'
# AGBAW 'revenueGrowth'
# AGBAW 'dividendYield'
# AGBAW 'payoutRatio'
# AGBAW 'fiveYearAvgDividendYield'
# AGBAW 'debtToEquity'
# AGBAW 'returnOnAssets'
# AGBAW 'returnOnEquity'
# AGBAW 'quickRatio'
# AGBAW 'currentRatio'
# AGD 'sector'
# AGD 'industry'
# AGD 'recommendationMean'
# AGD 'overallRisk'
# AGD 'beta'
# AGD 'trailingEps'
# AGD 'forwardEps'
# AGD 'trailingPE'
# AGD 'forwardPE'
# AGD 'pegRatio'
# AGD 'bookValue'
# AGD 'priceToBook'
# AGD 'ebitdaMargins'
# AGD 'profitMargins'
# AGD 'earningsGrowth'
# AGD 'revenueGrowth'
# AGD 'dividendYield'
# AGD 'payoutRatio'
# AGD 'fiveYearAvgDividendYield'
# AGD 'debtToEquity'
# AGD 'returnOnAssets'
# AGD 'returnOnEquity'
# AGD 'quickRatio'
# AGD 'currentRatio'
# AGE 'recommendationMean'
# AGE 'overallRisk'
# AGE 'forwardEps'
# AGE 'trailingPE'
# AGE 'forwardPE'
# AGE 'pegRatio'
# AGE 'priceToBook'
# AGE 'earningsGrowth'
# AGE 'dividendYield'
# AGE 'fiveYearAvgDividendYield'
# AGE 'debtToEquity'
# AGE 'returnOnEquity'
# AGEN 'trailingPE'
# AGEN 'pegRatio'
# AGEN 'priceToBook'
# AGEN 'earningsGrowth'
# AGEN 'dividendYield'
# AGEN 'fiveYearAvgDividendYield'
# AGEN 'debtToEquity'
# AGEN 'returnOnEquity'
# AGFY 'trailingPE'
# AGFY 'pegRatio'
# AGFY 'earningsGrowth'
# AGFY 'dividendYield'
# AGFY 'fiveYearAvgDividendYield'
# AGIL 'overallRisk'
# AGIL 'trailingPE'
# AGIL 'pegRatio'
# AGIL 'earningsGrowth'
# AGIL 'dividendYield'
# AGIL 'fiveYearAvgDividendYield'
# AGIO 'trailingPE'
# AGIO 'earningsGrowth'
# AGIO 'dividendYield'
# AGIO 'fiveYearAvgDividendYield'
# AGL 'trailingPE'
# AGL 'earningsGrowth'
# AGL 'dividendYield'
# AGL 'fiveYearAvgDividendYield'
# AGLE 'overallRisk'
# AGLE 'trailingPE'
# AGLE 'pegRatio'
# AGLE 'earningsGrowth'
# AGLE 'dividendYield'
# AGLE 'fiveYearAvgDividendYield'
# AGMH 'recommendationMean'
# AGMH 'overallRisk'
# AGMH 'forwardEps'
# AGMH 'forwardPE'
# AGMH 'pegRatio'
# AGMH 'earningsGrowth'
# AGMH 'revenueGrowth'
# AGMH 'dividendYield'
# AGMH 'fiveYearAvgDividendYield'
# AGNC 'trailingPE'
# AGNC 'earningsGrowth'
# AGNC 'revenueGrowth'
# AGNC 'payoutRatio'
# AGNCL 'recommendationMean'
# AGNCL 'trailingEps'
# AGNCL 'forwardEps'
# AGNCL 'trailingPE'
# AGNCL 'forwardPE'
# AGNCL 'pegRatio'
# AGNCL 'earningsGrowth'
# AGNCL 'revenueGrowth'
# AGNCL 'payoutRatio'
# AGNCL 'fiveYearAvgDividendYield'
# AGNCM 'recommendationMean'
# AGNCM 'forwardEps'
# AGNCM 'trailingPE'
# AGNCM 'forwardPE'
# AGNCM 'pegRatio'
# AGNCM 'earningsGrowth'
# AGNCM 'revenueGrowth'
# AGNCM 'payoutRatio'
# AGNCM 'fiveYearAvgDividendYield'
# AGNCN 'recommendationMean'
# AGNCN 'forwardEps'
# AGNCN 'trailingPE'
# AGNCN 'forwardPE'
# AGNCN 'pegRatio'
# AGNCN 'earningsGrowth'
# AGNCN 'revenueGrowth'
# AGNCN 'payoutRatio'
# AGNCO 'recommendationMean'
# AGNCO 'forwardEps'
# AGNCO 'trailingPE'
# AGNCO 'forwardPE'
# AGNCO 'pegRatio'
# AGNCO 'earningsGrowth'
# AGNCO 'revenueGrowth'
# AGNCO 'payoutRatio'
# AGNCO 'fiveYearAvgDividendYield'
# AGNCP 'recommendationMean'
# AGNCP 'forwardEps'
# AGNCP 'trailingPE'
# AGNCP 'forwardPE'
# AGNCP 'pegRatio'
# AGNCP 'earningsGrowth'
# AGNCP 'revenueGrowth'
# AGNCP 'payoutRatio'
# AGNCP 'fiveYearAvgDividendYield'
# AGRI 'overallRisk'
# AGRI 'beta'
# AGRI 'trailingPE'
# AGRI 'pegRatio'
# AGRI 'earningsGrowth'
# AGRI 'revenueGrowth'
# AGRI 'dividendYield'
# AGRI 'fiveYearAvgDividendYield'
# AGRIW 'recommendationMean'
# AGRIW 'overallRisk'
# AGRIW 'beta'
# AGRIW 'forwardEps'
# AGRIW 'trailingPE'
# AGRIW 'forwardPE'
# AGRIW 'pegRatio'
# AGRIW 'earningsGrowth'
# AGRIW 'revenueGrowth'
# AGRIW 'dividendYield'
# AGRIW 'payoutRatio'
# AGRIW 'fiveYearAvgDividendYield'
# AGRO 'fiveYearAvgDividendYield'
# AGRX 'pegRatio'
# AGRX 'priceToBook'
# AGRX 'earningsGrowth'
# AGRX 'dividendYield'
# AGRX 'fiveYearAvgDividendYield'
# AGRX 'debtToEquity'
# AGRX 'returnOnEquity'
# AGS 'dividendYield'
# AGS 'fiveYearAvgDividendYield'
# AGTI 'dividendYield'
# AGTI 'fiveYearAvgDividendYield'
# AGYS 'dividendYield'
# AGYS 'fiveYearAvgDividendYield'
# AHCO 'earningsGrowth'
# AHCO 'dividendYield'
# AHCO 'fiveYearAvgDividendYield'
# AHG 'recommendationMean'
# AHG 'overallRisk'
# AHG 'forwardEps'
# AHG 'trailingPE'
# AHG 'forwardPE'
# AHG 'pegRatio'
# AHG 'earningsGrowth'
# AHG 'revenueGrowth'
# AHG 'dividendYield'
# AHG 'fiveYearAvgDividendYield'
# AHI 'overallRisk'
# AHI 'forwardEps'
# AHI 'trailingPE'
# AHI 'forwardPE'
# AHI 'pegRatio'
# AHI 'earningsGrowth'
# AHI 'dividendYield'
# AHI 'fiveYearAvgDividendYield'
# AHL 'sector'
# AHL 'industry'
# AHL 'recommendationMean'
# AHL 'overallRisk'
# AHL 'beta'
# AHL 'trailingEps'
# AHL 'forwardEps'
# AHL 'trailingPE'
# AHL 'forwardPE'
# AHL 'pegRatio'
# AHL 'bookValue'
# AHL 'priceToBook'
# AHL 'ebitdaMargins'
# AHL 'profitMargins'
# AHL 'earningsGrowth'
# AHL 'revenueGrowth'
# AHL 'dividendYield'
# AHL 'payoutRatio'
# AHL 'fiveYearAvgDividendYield'
# AHL 'debtToEquity'
# AHL 'returnOnAssets'
# AHL 'returnOnEquity'
# AHL 'quickRatio'
# AHL 'currentRatio'
# AHT 'trailingPE'
# AHT 'priceToBook'
# AHT 'earningsGrowth'
# AHT 'dividendYield'
# AHT 'fiveYearAvgDividendYield'
# AHT 'debtToEquity'
# AHT 'returnOnEquity'
# AI 'trailingPE'
# AI 'earningsGrowth'
# AI 'dividendYield'
# AI 'fiveYearAvgDividendYield'
# AIB 'recommendationMean'
# AIB 'overallRisk'
# AIB 'beta'
# AIB 'forwardEps'
# AIB 'forwardPE'
# AIB 'pegRatio'
# AIB 'priceToBook'
# AIB 'earningsGrowth'
# AIB 'revenueGrowth'
# AIB 'dividendYield'
# AIB 'fiveYearAvgDividendYield'
# AIB 'debtToEquity'
# AIB 'returnOnAssets'
# AIB 'returnOnEquity'
# AIC 'sector'
# AIC 'industry'
# AIC 'recommendationMean'
# AIC 'overallRisk'
# AIC 'beta'
# AIC 'trailingEps'
# AIC 'forwardEps'
# AIC 'trailingPE'
# AIC 'forwardPE'
# AIC 'pegRatio'
# AIC 'bookValue'
# AIC 'priceToBook'
# AIC 'ebitdaMargins'
# AIC 'profitMargins'
# AIC 'earningsGrowth'
# AIC 'revenueGrowth'
# AIC 'dividendYield'
# AIC 'payoutRatio'
# AIC 'fiveYearAvgDividendYield'
# AIC 'debtToEquity'
# AIC 'returnOnAssets'
# AIC 'returnOnEquity'
# AIC 'quickRatio'
# AIC 'currentRatio'
# AIF 'recommendationMean'
# AIF 'overallRisk'
# AIF 'trailingPE'
# AIF 'pegRatio'
# AIF 'payoutRatio'
# AIH 'overallRisk'
# AIH 'trailingPE'
# AIH 'pegRatio'
# AIH 'earningsGrowth'
# AIH 'dividendYield'
# AIH 'fiveYearAvgDividendYield'
# AIH 'returnOnEquity'
# AIHS 'recommendationMean'
# AIHS 'overallRisk'
# AIHS 'forwardEps'
# AIHS 'trailingPE'
# AIHS 'forwardPE'
# AIHS 'pegRatio'
# AIHS 'earningsGrowth'
# AIHS 'dividendYield'
# AIHS 'fiveYearAvgDividendYield'
# AIM 'overallRisk'
# AIM 'trailingPE'
# AIM 'earningsGrowth'
# AIM 'dividendYield'
# AIM 'fiveYearAvgDividendYield'
# AIMBU 'sector'
# AIMBU 'industry'
# AIMBU 'recommendationMean'
# AIMBU 'overallRisk'
# AIMBU 'beta'
# AIMBU 'trailingEps'
# AIMBU 'forwardEps'
# AIMBU 'trailingPE'
# AIMBU 'forwardPE'
# AIMBU 'pegRatio'
# AIMBU 'bookValue'
# AIMBU 'priceToBook'
# AIMBU 'ebitdaMargins'
# AIMBU 'profitMargins'
# AIMBU 'earningsGrowth'
# AIMBU 'revenueGrowth'
# AIMBU 'dividendYield'
# AIMBU 'payoutRatio'
# AIMBU 'fiveYearAvgDividendYield'
# AIMBU 'debtToEquity'
# AIMBU 'returnOnAssets'
# AIMBU 'returnOnEquity'
# AIMBU 'quickRatio'
# AIMBU 'currentRatio'
# AIMD 'recommendationMean'
# AIMD 'overallRisk'
# AIMD 'forwardEps'
# AIMD 'trailingPE'
# AIMD 'forwardPE'
# AIMD 'pegRatio'
# AIMD 'earningsGrowth'
# AIMD 'dividendYield'
# AIMD 'fiveYearAvgDividendYield'
# AIMDW 'sector'
# AIMDW 'industry'
# AIMDW 'recommendationMean'
# AIMDW 'overallRisk'
# AIMDW 'beta'
# AIMDW 'trailingEps'
# AIMDW 'forwardEps'
# AIMDW 'trailingPE'
# AIMDW 'forwardPE'
# AIMDW 'pegRatio'
# AIMDW 'bookValue'
# AIMDW 'priceToBook'
# AIMDW 'ebitdaMargins'
# AIMDW 'profitMargins'
# AIMDW 'earningsGrowth'
# AIMDW 'revenueGrowth'
# AIMDW 'dividendYield'
# AIMDW 'payoutRatio'
# AIMDW 'fiveYearAvgDividendYield'
# AIMDW 'debtToEquity'
# AIMDW 'returnOnAssets'
# AIMDW 'returnOnEquity'
# AIMDW 'quickRatio'
# AIMDW 'currentRatio'
# AINC 'overallRisk'
# AINC 'trailingPE'
# AINC 'pegRatio'
# AINC 'priceToBook'
# AINC 'earningsGrowth'
# AINC 'dividendYield'
# AINC 'fiveYearAvgDividendYield'
# AIO 'sector'
# AIO 'industry'
# AIO 'recommendationMean'
# AIO 'overallRisk'
# AIO 'beta'
# AIO 'forwardEps'
# AIO 'trailingPE'
# AIO 'forwardPE'
# AIO 'pegRatio'
# AIO 'bookValue'
# AIO 'priceToBook'
# AIO 'earningsGrowth'
# AIO 'revenueGrowth'
# AIO 'payoutRatio'
# AIO 'fiveYearAvgDividendYield'
# AIO 'debtToEquity'
# AIO 'returnOnAssets'
# AIO 'returnOnEquity'
# AIO 'quickRatio'
# AIO 'currentRatio'
# AIP 'beta'
# AIP 'trailingPE'
# AIP 'pegRatio'
# AIP 'earningsGrowth'
# AIP 'dividendYield'
# AIP 'fiveYearAvgDividendYield'
# AIR 'pegRatio'
# AIR 'dividendYield'
# AIR 'fiveYearAvgDividendYield'
# AIRC 'pegRatio'
# AIRC 'earningsGrowth'
# AIRG 'overallRisk'
# AIRG 'trailingPE'
# AIRG 'earningsGrowth'
# AIRG 'dividendYield'
# AIRG 'fiveYearAvgDividendYield'
# AIRI 'overallRisk'
# AIRI 'trailingPE'
# AIRI 'pegRatio'
# AIRI 'earningsGrowth'
# AIRI 'dividendYield'
# AIRI 'fiveYearAvgDividendYield'
# AIRS 'beta'
# AIRS 'trailingPE'
# AIRS 'earningsGrowth'
# AIRS 'dividendYield'
# AIRS 'fiveYearAvgDividendYield'
# AIRT 'recommendationMean'
# AIRT 'overallRisk'
# AIRT 'forwardEps'
# AIRT 'trailingPE'
# AIRT 'forwardPE'
# AIRT 'pegRatio'
# AIRT 'earningsGrowth'
# AIRT 'dividendYield'
# AIRT 'fiveYearAvgDividendYield'
# AIRTP 'recommendationMean'
# AIRTP 'overallRisk'
# AIRTP 'forwardEps'
# AIRTP 'forwardPE'
# AIRTP 'pegRatio'
# AIRTP 'earningsGrowth'
# AIRTP 'payoutRatio'
# AIRTP 'fiveYearAvgDividendYield'
# AIU 'overallRisk'
# AIU 'trailingPE'
# AIU 'priceToBook'
# AIU 'earningsGrowth'
# AIU 'revenueGrowth'
# AIU 'dividendYield'
# AIU 'fiveYearAvgDividendYield'
# AIU 'debtToEquity'
# AIU 'returnOnEquity'
# AIV 'pegRatio'
# AIV 'earningsGrowth'
# AIV 'dividendYield'
# AIV 'fiveYearAvgDividendYield'
# AIXI 'recommendationMean'
# AIXI 'overallRisk'
# AIXI 'beta'
# AIXI 'forwardEps'
# AIXI 'trailingPE'
# AIXI 'forwardPE'
# AIXI 'pegRatio'
# AIXI 'priceToBook'
# AIXI 'earningsGrowth'
# AIXI 'dividendYield'
# AIXI 'fiveYearAvgDividendYield'
# AIXI 'debtToEquity'
# AIXI 'returnOnEquity'
# AIZN 'sector'
# AIZN 'industry'
# AIZN 'recommendationMean'
# AIZN 'overallRisk'
# AIZN 'beta'
# AIZN 'trailingEps'
# AIZN 'forwardEps'
# AIZN 'trailingPE'
# AIZN 'forwardPE'
# AIZN 'pegRatio'
# AIZN 'bookValue'
# AIZN 'priceToBook'
# AIZN 'ebitdaMargins'
# AIZN 'profitMargins'
# AIZN 'earningsGrowth'
# AIZN 'revenueGrowth'
# AIZN 'dividendYield'
# AIZN 'payoutRatio'
# AIZN 'fiveYearAvgDividendYield'
# AIZN 'debtToEquity'
# AIZN 'returnOnAssets'
# AIZN 'returnOnEquity'
# AIZN 'quickRatio'
# AIZN 'currentRatio'
# AJX 'trailingPE'
# AJX 'pegRatio'
# AJX 'earningsGrowth'
# AJX 'payoutRatio'
# AJXA 'sector'
# AJXA 'industry'
# AJXA 'recommendationMean'
# AJXA 'overallRisk'
# AJXA 'beta'
# AJXA 'trailingEps'
# AJXA 'forwardEps'
# AJXA 'forwardPE'
# AJXA 'pegRatio'
# AJXA 'bookValue'
# AJXA 'priceToBook'
# AJXA 'ebitdaMargins'
# AJXA 'profitMargins'
# AJXA 'earningsGrowth'
# AJXA 'revenueGrowth'
# AJXA 'dividendYield'
# AJXA 'payoutRatio'
# AJXA 'fiveYearAvgDividendYield'
# AJXA 'debtToEquity'
# AJXA 'returnOnAssets'
# AJXA 'returnOnEquity'
# AJXA 'quickRatio'
# AJXA 'currentRatio'
# AKA 'beta'
# AKA 'trailingPE'
# AKA 'earningsGrowth'
# AKA 'dividendYield'
# AKA 'fiveYearAvgDividendYield'
# AKAM 'dividendYield'
# AKAM 'fiveYearAvgDividendYield'
# AKAN 'recommendationMean'
# AKAN 'overallRisk'
# AKAN 'beta'
# AKAN 'forwardEps'
# AKAN 'trailingPE'
# AKAN 'forwardPE'
# AKAN 'pegRatio'
# AKAN 'earningsGrowth'
# AKAN 'revenueGrowth'
# AKAN 'dividendYield'
# AKAN 'fiveYearAvgDividendYield'
# AKBA 'trailingPE'
# AKBA 'pegRatio'
# AKBA 'priceToBook'
# AKBA 'earningsGrowth'
# AKBA 'dividendYield'
# AKBA 'fiveYearAvgDividendYield'
# AKBA 'debtToEquity'
# AKLI 'overallRisk'
# AKLI 'trailingPE'
# AKLI 'pegRatio'
# AKLI 'earningsGrowth'
# AKLI 'dividendYield'
# AKLI 'fiveYearAvgDividendYield'
# AKO 'shortName'
# AKO 'sector'
# AKO 'industry'
# AKO 'recommendationMean'
# AKO 'overallRisk'
# AKO 'beta'
# AKO 'trailingEps'
# AKO 'forwardEps'
# AKO 'trailingPE'
# AKO 'forwardPE'
# AKO 'pegRatio'
# AKO 'bookValue'
# AKO 'priceToBook'
# AKO 'ebitdaMargins'
# AKO 'profitMargins'
# AKO 'earningsGrowth'
# AKO 'revenueGrowth'
# AKO 'dividendYield'
# AKO 'payoutRatio'
# AKO 'fiveYearAvgDividendYield'
# AKO 'debtToEquity'
# AKO 'returnOnAssets'
# AKO 'returnOnEquity'
# AKO 'quickRatio'
# AKO 'currentRatio'
# AKR 'trailingPE'
# AKR 'earningsGrowth'
# AKR 'payoutRatio'
# AKRO 'trailingPE'
# AKRO 'earningsGrowth'
# AKRO 'revenueGrowth'
# AKRO 'dividendYield'
# AKRO 'fiveYearAvgDividendYield'
# AKTS 'trailingPE'
# AKTS 'pegRatio'
# AKTS 'earningsGrowth'
# AKTS 'dividendYield'
# AKTS 'fiveYearAvgDividendYield'
# AKTX 'overallRisk'
# AKTX 'trailingPE'
# AKTX 'pegRatio'
# AKTX 'earningsGrowth'
# AKTX 'revenueGrowth'
# AKTX 'dividendYield'
# AKTX 'fiveYearAvgDividendYield'
# AKTX 'debtToEquity'
# AKU 'overallRisk'
# AKU 'trailingPE'
# AKU 'pegRatio'
# AKU 'priceToBook'
# AKU 'earningsGrowth'
# AKU 'dividendYield'
# AKU 'fiveYearAvgDividendYield'
# AKYA 'trailingPE'
# AKYA 'pegRatio'
# AKYA 'earningsGrowth'
# AKYA 'dividendYield'
# AKYA 'fiveYearAvgDividendYield'
# ALAR 'overallRisk'
# ALAR 'trailingPE'
# ALAR 'pegRatio'
# ALAR 'earningsGrowth'
# ALAR 'dividendYield'
# ALAR 'fiveYearAvgDividendYield'
# ALBT 'recommendationMean'
# ALBT 'overallRisk'
# ALBT 'forwardEps'
# ALBT 'trailingPE'
# ALBT 'forwardPE'
# ALBT 'pegRatio'
# ALBT 'priceToBook'
# ALBT 'earningsGrowth'
# ALBT 'dividendYield'
# ALBT 'fiveYearAvgDividendYield'
# ALC 'fiveYearAvgDividendYield'
# ALCC 'recommendationMean'
# ALCC 'overallRisk'
# ALCC 'forwardEps'
# ALCC 'forwardPE'
# ALCC 'pegRatio'
# ALCC 'priceToBook'
# ALCC 'earningsGrowth'
# ALCC 'revenueGrowth'
# ALCC 'dividendYield'
# ALCC 'fiveYearAvgDividendYield'
# ALCC 'debtToEquity'
# ALCC 'returnOnEquity'
# ALCO 'trailingPE'
# ALCO 'pegRatio'
# ALCO 'payoutRatio'
# ALCY 'recommendationMean'
# ALCY 'overallRisk'
# ALCY 'beta'
# ALCY 'forwardEps'
# ALCY 'forwardPE'
# ALCY 'pegRatio'
# ALCY 'earningsGrowth'
# ALCY 'revenueGrowth'
# ALCY 'dividendYield'
# ALCY 'fiveYearAvgDividendYield'
# ALCY 'returnOnAssets'
# ALCY 'returnOnEquity'
# ALCY 'quickRatio'
# ALCY 'currentRatio'
# ALCYU 'recommendationMean'
# ALCYU 'overallRisk'
# ALCYU 'beta'
# ALCYU 'trailingEps'
# ALCYU 'forwardEps'
# ALCYU 'trailingPE'
# ALCYU 'forwardPE'
# ALCYU 'pegRatio'
# ALCYU 'earningsGrowth'
# ALCYU 'revenueGrowth'
# ALCYU 'dividendYield'
# ALCYU 'payoutRatio'
# ALCYU 'fiveYearAvgDividendYield'
# ALCYU 'returnOnAssets'
# ALCYU 'returnOnEquity'
# ALCYU 'quickRatio'
# ALCYU 'currentRatio'
# ALCYW 'sector'
# ALCYW 'industry'
# ALCYW 'recommendationMean'
# ALCYW 'overallRisk'
# ALCYW 'beta'
# ALCYW 'trailingEps'
# ALCYW 'forwardEps'
# ALCYW 'trailingPE'
# ALCYW 'forwardPE'
# ALCYW 'pegRatio'
# ALCYW 'bookValue'
# ALCYW 'priceToBook'
# ALCYW 'ebitdaMargins'
# ALCYW 'profitMargins'
# ALCYW 'earningsGrowth'
# ALCYW 'revenueGrowth'
# ALCYW 'dividendYield'
# ALCYW 'payoutRatio'
# ALCYW 'fiveYearAvgDividendYield'
# ALCYW 'debtToEquity'
# ALCYW 'returnOnAssets'
# ALCYW 'returnOnEquity'
# ALCYW 'quickRatio'
# ALCYW 'currentRatio'
# ALDX 'overallRisk'
# ALDX 'trailingPE'
# ALDX 'earningsGrowth'
# ALDX 'revenueGrowth'
# ALDX 'dividendYield'
# ALDX 'fiveYearAvgDividendYield'
# ALEC 'trailingPE'
# ALEC 'dividendYield'
# ALEC 'fiveYearAvgDividendYield'
# ALEX 'pegRatio'
# ALEX 'fiveYearAvgDividendYield'
# ALGM 'dividendYield'
# ALGM 'fiveYearAvgDividendYield'
# ALGN 'dividendYield'
# ALGN 'fiveYearAvgDividendYield'
# ALGS 'beta'
# ALGS 'trailingPE'
# ALGS 'pegRatio'
# ALGS 'earningsGrowth'
# ALGS 'dividendYield'
# ALGS 'fiveYearAvgDividendYield'
# ALGT 'fiveYearAvgDividendYield'
# ALGT 'returnOnAssets'
# ALGT 'returnOnEquity'
# ALGT 'quickRatio'
# ALGT 'currentRatio'
# ALHC 'trailingPE'
# ALHC 'earningsGrowth'
# ALHC 'dividendYield'
# ALHC 'fiveYearAvgDividendYield'
# ALIM 'overallRisk'
# ALIM 'trailingPE'
# ALIM 'pegRatio'
# ALIM 'priceToBook'
# ALIM 'earningsGrowth'
# ALIM 'dividendYield'
# ALIM 'fiveYearAvgDividendYield'
# ALIM 'debtToEquity'
# ALIM 'returnOnEquity'
# ALIT 'trailingPE'
# ALIT 'earningsGrowth'
# ALIT 'dividendYield'
# ALIT 'fiveYearAvgDividendYield'
# ALK 'dividendYield'
# ALK 'fiveYearAvgDividendYield'
# ALKS 'trailingPE'
# ALKS 'earningsGrowth'
# ALKS 'dividendYield'
# ALKS 'fiveYearAvgDividendYield'
# ALKT 'trailingPE'
# ALKT 'earningsGrowth'
# ALKT 'dividendYield'
# ALKT 'fiveYearAvgDividendYield'
# ALL 'trailingPE'
# ALL 'earningsGrowth'
# ALL 'payoutRatio'
# ALLG 'overallRisk'
# ALLG 'trailingPE'
# ALLG 'pegRatio'
# ALLG 'earningsGrowth'
# ALLG 'dividendYield'
# ALLG 'fiveYearAvgDividendYield'
# ALLG 'returnOnAssets'
# ALLG 'returnOnEquity'
# ALLK 'trailingPE'
# ALLK 'earningsGrowth'
# ALLK 'revenueGrowth'
# ALLK 'dividendYield'
# ALLK 'fiveYearAvgDividendYield'
# ALLO 'trailingPE'
# ALLO 'earningsGrowth'
# ALLO 'dividendYield'
# ALLO 'fiveYearAvgDividendYield'
# ALLR 'overallRisk'
# ALLR 'beta'
# ALLR 'pegRatio'
# ALLR 'priceToBook'
# ALLR 'earningsGrowth'
# ALLR 'revenueGrowth'
# ALLR 'dividendYield'
# ALLR 'fiveYearAvgDividendYield'
# ALLR 'debtToEquity'
# ALLT 'overallRisk'
# ALLT 'trailingPE'
# ALLT 'earningsGrowth'
# ALLT 'dividendYield'
# ALLT 'fiveYearAvgDividendYield'
# ALLY 'debtToEquity'
# ALLY 'quickRatio'
# ALLY 'currentRatio'
# ALNY 'trailingPE'
# ALNY 'priceToBook'
# ALNY 'earningsGrowth'
# ALNY 'dividendYield'
# ALNY 'fiveYearAvgDividendYield'
# ALNY 'debtToEquity'
# ALNY 'returnOnEquity'
# ALOR 'recommendationMean'
# ALOR 'overallRisk'
# ALOR 'beta'
# ALOR 'forwardEps'
# ALOR 'forwardPE'
# ALOR 'pegRatio'
# ALOR 'priceToBook'
# ALOR 'earningsGrowth'
# ALOR 'revenueGrowth'
# ALOR 'dividendYield'
# ALOR 'fiveYearAvgDividendYield'
# ALOR 'debtToEquity'
# ALOR 'returnOnAssets'
# ALOR 'returnOnEquity'
# ALOT 'overallRisk'
# ALOT 'pegRatio'
# ALOT 'dividendYield'
# ALOT 'fiveYearAvgDividendYield'
# ALPN 'trailingPE'
# ALPN 'pegRatio'
# ALPN 'earningsGrowth'
# ALPN 'dividendYield'
# ALPN 'fiveYearAvgDividendYield'
# ALPP 'overallRisk'
# ALPP 'trailingPE'
# ALPP 'pegRatio'
# ALPP 'earningsGrowth'
# ALPP 'dividendYield'
# ALPP 'fiveYearAvgDividendYield'
# ALRM 'dividendYield'
# ALRM 'fiveYearAvgDividendYield'
# ALRN 'overallRisk'
# ...
# YOTA 'forwardEps'
# YOTA 'forwardPE'
# YOTA 'pegRatio'
# YOTA 'priceToBook'
# YOTA 'earningsGrowth'
# YOTA 'revenueGrowth'
# YOTA 'dividendYield'
# YOTA 'fiveYearAvgDividendYield'
# YOTA 'debtToEquity'
# YOTA 'returnOnAssets'
# YOTA 'returnOnEquity'
# YOTAR 'sector'
# YOTAR 'industry'
# YOTAR 'recommendationMean'
# YOTAR 'overallRisk'
# YOTAR 'beta'
# YOTAR 'trailingEps'
# YOTAR 'forwardEps'
# YOTAR 'trailingPE'
# YOTAR 'forwardPE'
# YOTAR 'pegRatio'
# YOTAR 'bookValue'
# YOTAR 'priceToBook'
# YOTAR 'ebitdaMargins'
# YOTAR 'profitMargins'
# YOTAR 'earningsGrowth'
# YOTAR 'revenueGrowth'
# YOTAR 'dividendYield'
# YOTAR 'payoutRatio'
# YOTAR 'fiveYearAvgDividendYield'
# YOTAR 'debtToEquity'
# YOTAR 'returnOnAssets'
# YOTAR 'returnOnEquity'
# YOTAR 'quickRatio'
# YOTAR 'currentRatio'
# YOTAW 'sector'
# YOTAW 'industry'
# YOTAW 'recommendationMean'
# YOTAW 'overallRisk'
# YOTAW 'beta'
# YOTAW 'trailingEps'
# YOTAW 'forwardEps'
# YOTAW 'trailingPE'
# YOTAW 'forwardPE'
# YOTAW 'pegRatio'
# YOTAW 'bookValue'
# YOTAW 'priceToBook'
# YOTAW 'ebitdaMargins'
# YOTAW 'profitMargins'
# YOTAW 'earningsGrowth'
# YOTAW 'revenueGrowth'
# YOTAW 'dividendYield'
# YOTAW 'payoutRatio'
# YOTAW 'fiveYearAvgDividendYield'
# YOTAW 'debtToEquity'
# YOTAW 'returnOnAssets'
# YOTAW 'returnOnEquity'
# YOTAW 'quickRatio'
# YOTAW 'currentRatio'
# YOU 'trailingPE'
# YOU 'pegRatio'
# YOU 'earningsGrowth'
# YOU 'fiveYearAvgDividendYield'
# YPF 'overallRisk'
# YPF 'dividendYield'
# YPF 'fiveYearAvgDividendYield'
# YQ 'overallRisk'
# YQ 'trailingPE'
# YQ 'pegRatio'
# YQ 'earningsGrowth'
# YQ 'dividendYield'
# YQ 'fiveYearAvgDividendYield'
# YRD 'overallRisk'
# YRD 'pegRatio'
# YRD 'dividendYield'
# YRD 'fiveYearAvgDividendYield'
# YRD 'returnOnAssets'
# YS 'recommendationMean'
# YS 'overallRisk'
# YS 'forwardEps'
# YS 'trailingPE'
# YS 'forwardPE'
# YS 'pegRatio'
# YS 'earningsGrowth'
# YS 'dividendYield'
# YS 'fiveYearAvgDividendYield'
# YSBPW 'sector'
# YSBPW 'industry'
# YSBPW 'recommendationMean'
# YSBPW 'overallRisk'
# YSBPW 'beta'
# YSBPW 'trailingEps'
# YSBPW 'forwardEps'
# YSBPW 'trailingPE'
# YSBPW 'forwardPE'
# YSBPW 'pegRatio'
# YSBPW 'bookValue'
# YSBPW 'priceToBook'
# YSBPW 'ebitdaMargins'
# YSBPW 'profitMargins'
# YSBPW 'earningsGrowth'
# YSBPW 'revenueGrowth'
# YSBPW 'dividendYield'
# YSBPW 'payoutRatio'
# YSBPW 'fiveYearAvgDividendYield'
# YSBPW 'debtToEquity'
# YSBPW 'returnOnAssets'
# YSBPW 'returnOnEquity'
# YSBPW 'quickRatio'
# YSBPW 'currentRatio'
# YSG 'overallRisk'
# YSG 'trailingPE'
# YSG 'pegRatio'
# YSG 'earningsGrowth'
# YSG 'dividendYield'
# YSG 'fiveYearAvgDividendYield'
# YTEN 'overallRisk'
# YTEN 'trailingPE'
# YTEN 'pegRatio'
# YTEN 'earningsGrowth'
# YTEN 'dividendYield'
# YTEN 'fiveYearAvgDividendYield'
# YTRA 'overallRisk'
# YTRA 'trailingPE'
# YTRA 'pegRatio'
# YTRA 'earningsGrowth'
# YTRA 'dividendYield'
# YTRA 'fiveYearAvgDividendYield'
# YUM 'priceToBook'
# YUM 'debtToEquity'
# YUM 'returnOnEquity'
# YVR 'recommendationMean'
# YVR 'overallRisk'
# YVR 'forwardEps'
# YVR 'trailingPE'
# YVR 'forwardPE'
# YVR 'pegRatio'
# YVR 'earningsGrowth'
# YVR 'dividendYield'
# YVR 'fiveYearAvgDividendYield'
# YY 'overallRisk'
# YY 'earningsGrowth'
# YY 'fiveYearAvgDividendYield'
# Z 'trailingPE'
# Z 'earningsGrowth'
# Z 'dividendYield'
# Z 'fiveYearAvgDividendYield'
# ZAPP 'recommendationMean'
# ZAPP 'overallRisk'
# ZAPP 'beta'
# ZAPP 'forwardEps'
# ZAPP 'trailingPE'
# ZAPP 'forwardPE'
# ZAPP 'pegRatio'
# ZAPP 'earningsGrowth'
# ZAPP 'revenueGrowth'
# ZAPP 'dividendYield'
# ZAPP 'fiveYearAvgDividendYield'
# ZAPP 'debtToEquity'
# ZAPPW 'sector'
# ZAPPW 'industry'
# ZAPPW 'recommendationMean'
# ZAPPW 'overallRisk'
# ZAPPW 'beta'
# ZAPPW 'trailingEps'
# ZAPPW 'forwardEps'
# ZAPPW 'trailingPE'
# ZAPPW 'forwardPE'
# ZAPPW 'pegRatio'
# ZAPPW 'bookValue'
# ZAPPW 'priceToBook'
# ZAPPW 'ebitdaMargins'
# ZAPPW 'profitMargins'
# ZAPPW 'earningsGrowth'
# ZAPPW 'revenueGrowth'
# ZAPPW 'dividendYield'
# ZAPPW 'payoutRatio'
# ZAPPW 'fiveYearAvgDividendYield'
# ZAPPW 'debtToEquity'
# ZAPPW 'returnOnAssets'
# ZAPPW 'returnOnEquity'
# ZAPPW 'quickRatio'
# ZAPPW 'currentRatio'
# ZBRA 'earningsGrowth'
# ZBRA 'dividendYield'
# ZBRA 'fiveYearAvgDividendYield'
# ZCMD 'recommendationMean'
# ZCMD 'overallRisk'
# ZCMD 'forwardEps'
# ZCMD 'trailingPE'
# ZCMD 'forwardPE'
# ZCMD 'pegRatio'
# ZCMD 'earningsGrowth'
# ZCMD 'dividendYield'
# ZCMD 'fiveYearAvgDividendYield'
# ZD 'earningsGrowth'
# ZD 'dividendYield'
# ZD 'fiveYearAvgDividendYield'
# ZDGE 'overallRisk'
# ZDGE 'trailingPE'
# ZDGE 'pegRatio'
# ZDGE 'earningsGrowth'
# ZDGE 'dividendYield'
# ZDGE 'fiveYearAvgDividendYield'
# ZENV 'overallRisk'
# ZENV 'trailingPE'
# ZENV 'pegRatio'
# ZENV 'earningsGrowth'
# ZENV 'dividendYield'
# ZENV 'fiveYearAvgDividendYield'
# ZEPP 'overallRisk'
# ZEPP 'trailingPE'
# ZEPP 'earningsGrowth'
# ZEPP 'dividendYield'
# ZEPP 'fiveYearAvgDividendYield'
# ZETA 'trailingPE'
# ZETA 'earningsGrowth'
# ZETA 'dividendYield'
# ZETA 'fiveYearAvgDividendYield'
# ZEV 'pegRatio'
# ZEV 'earningsGrowth'
# ZEV 'dividendYield'
# ZEV 'fiveYearAvgDividendYield'
# ZFOX 'overallRisk'
# ZFOX 'trailingPE'
# ZFOX 'pegRatio'
# ZFOX 'earningsGrowth'
# ZFOX 'dividendYield'
# ZFOX 'fiveYearAvgDividendYield'
# ZFOXW 'shortName'
# ZFOXW 'sector'
# ZFOXW 'industry'
# ZFOXW 'recommendationMean'
# ZFOXW 'overallRisk'
# ZFOXW 'beta'
# ZFOXW 'trailingEps'
# ZFOXW 'forwardEps'
# ZFOXW 'trailingPE'
# ZFOXW 'forwardPE'
# ZFOXW 'pegRatio'
# ZFOXW 'bookValue'
# ZFOXW 'priceToBook'
# ZFOXW 'ebitdaMargins'
# ZFOXW 'profitMargins'
# ZFOXW 'earningsGrowth'
# ZFOXW 'revenueGrowth'
# ZFOXW 'dividendYield'
# ZFOXW 'payoutRatio'
# ZFOXW 'fiveYearAvgDividendYield'
# ZFOXW 'debtToEquity'
# ZFOXW 'returnOnAssets'
# ZFOXW 'returnOnEquity'
# ZFOXW 'quickRatio'
# ZFOXW 'currentRatio'
# ZG 'trailingPE'
# ZG 'earningsGrowth'
# ZG 'dividendYield'
# ZG 'fiveYearAvgDividendYield'
# ZGN 'pegRatio'
# ZGN 'earningsGrowth'
# ZGN 'fiveYearAvgDividendYield'
# ZH 'overallRisk'
# ZH 'trailingPE'
# ZH 'pegRatio'
# ZH 'earningsGrowth'
# ZH 'dividendYield'
# ZH 'fiveYearAvgDividendYield'
# ZI 'dividendYield'
# ZI 'fiveYearAvgDividendYield'
# ZIM 'overallRisk'
# ZIM 'earningsGrowth'
# ZIM 'dividendYield'
# ZIM 'fiveYearAvgDividendYield'
# ZIMV 'beta'
# ZIMV 'trailingPE'
# ZIMV 'earningsGrowth'
# ZIMV 'dividendYield'
# ZIMV 'fiveYearAvgDividendYield'
# ZING 'recommendationMean'
# ZING 'overallRisk'
# ZING 'beta'
# ZING 'forwardEps'
# ZING 'forwardPE'
# ZING 'pegRatio'
# ZING 'priceToBook'
# ZING 'earningsGrowth'
# ZING 'revenueGrowth'
# ZING 'dividendYield'
# ZING 'fiveYearAvgDividendYield'
# ZING 'debtToEquity'
# ZING 'returnOnEquity'
# ZION 'debtToEquity'
# ZION 'quickRatio'
# ZION 'currentRatio'
# ZIONL 'sector'
# ZIONL 'industry'
# ZIONL 'recommendationMean'
# ZIONL 'overallRisk'
# ZIONL 'beta'
# ZIONL 'trailingEps'
# ZIONL 'forwardEps'
# ZIONL 'trailingPE'
# ZIONL 'forwardPE'
# ZIONL 'pegRatio'
# ZIONL 'bookValue'
# ZIONL 'priceToBook'
# ZIONL 'ebitdaMargins'
# ZIONL 'profitMargins'
# ZIONL 'earningsGrowth'
# ZIONL 'revenueGrowth'
# ZIONL 'dividendYield'
# ZIONL 'payoutRatio'
# ZIONL 'fiveYearAvgDividendYield'
# ZIONL 'debtToEquity'
# ZIONL 'returnOnAssets'
# ZIONL 'returnOnEquity'
# ZIONL 'quickRatio'
# ZIONL 'currentRatio'
# ZIONO 'recommendationMean'
# ZIONO 'forwardEps'
# ZIONO 'forwardPE'
# ZIONO 'pegRatio'
# ZIONO 'payoutRatio'
# ZIONO 'debtToEquity'
# ZIONO 'quickRatio'
# ZIONO 'currentRatio'
# ZIONP 'recommendationMean'
# ZIONP 'forwardEps'
# ZIONP 'forwardPE'
# ZIONP 'pegRatio'
# ZIONP 'payoutRatio'
# ZIONP 'debtToEquity'
# ZIONP 'quickRatio'
# ZIONP 'currentRatio'
# ZIP 'priceToBook'
# ZIP 'dividendYield'
# ZIP 'fiveYearAvgDividendYield'
# ZIP 'debtToEquity'
# ZIVO 'overallRisk'
# ZIVO 'trailingPE'
# ZIVO 'pegRatio'
# ZIVO 'priceToBook'
# ZIVO 'earningsGrowth'
# ZIVO 'revenueGrowth'
# ZIVO 'dividendYield'
# ZIVO 'fiveYearAvgDividendYield'
# ZIVO 'debtToEquity'
# ZIVOW 'sector'
# ZIVOW 'industry'
# ZIVOW 'recommendationMean'
# ZIVOW 'overallRisk'
# ZIVOW 'beta'
# ZIVOW 'trailingEps'
# ZIVOW 'forwardEps'
# ZIVOW 'trailingPE'
# ZIVOW 'forwardPE'
# ZIVOW 'pegRatio'
# ZIVOW 'bookValue'
# ZIVOW 'priceToBook'
# ZIVOW 'ebitdaMargins'
# ZIVOW 'profitMargins'
# ZIVOW 'earningsGrowth'
# ZIVOW 'revenueGrowth'
# ZIVOW 'dividendYield'
# ZIVOW 'payoutRatio'
# ZIVOW 'fiveYearAvgDividendYield'
# ZIVOW 'debtToEquity'
# ZIVOW 'returnOnAssets'
# ZIVOW 'returnOnEquity'
# ZIVOW 'quickRatio'
# ZIVOW 'currentRatio'
# ZJYL 'recommendationMean'
# ZJYL 'overallRisk'
# ZJYL 'beta'
# ZJYL 'forwardEps'
# ZJYL 'forwardPE'
# ZJYL 'pegRatio'
# ZJYL 'dividendYield'
# ZJYL 'fiveYearAvgDividendYield'
# ZJYL 'debtToEquity'
# ZKIN 'recommendationMean'
# ZKIN 'overallRisk'
# ZKIN 'forwardEps'
# ZKIN 'trailingPE'
# ZKIN 'forwardPE'
# ZKIN 'pegRatio'
# ZKIN 'earningsGrowth'
# ZKIN 'dividendYield'
# ZKIN 'fiveYearAvgDividendYield'
# ZLAB 'overallRisk'
# ZLAB 'trailingPE'
# ZLAB 'earningsGrowth'
# ZLAB 'dividendYield'
# ZLAB 'fiveYearAvgDividendYield'
# ZLS 'recommendationMean'
# ZLS 'overallRisk'
# ZLS 'beta'
# ZLS 'trailingEps'
# ZLS 'forwardEps'
# ZLS 'trailingPE'
# ZLS 'forwardPE'
# ZLS 'pegRatio'
# ZLS 'priceToBook'
# ZLS 'earningsGrowth'
# ZLS 'revenueGrowth'
# ZLS 'dividendYield'
# ZLS 'fiveYearAvgDividendYield'
# ZLS 'debtToEquity'
# ZLS 'returnOnEquity'
# ZLSWW 'shortName'
# ZLSWW 'sector'
# ZLSWW 'industry'
# ZLSWW 'recommendationMean'
# ZLSWW 'overallRisk'
# ZLSWW 'beta'
# ZLSWW 'trailingEps'
# ZLSWW 'forwardEps'
# ZLSWW 'trailingPE'
# ZLSWW 'forwardPE'
# ZLSWW 'pegRatio'
# ZLSWW 'bookValue'
# ZLSWW 'priceToBook'
# ZLSWW 'ebitdaMargins'
# ZLSWW 'profitMargins'
# ZLSWW 'earningsGrowth'
# ZLSWW 'revenueGrowth'
# ZLSWW 'dividendYield'
# ZLSWW 'payoutRatio'
# ZLSWW 'fiveYearAvgDividendYield'
# ZLSWW 'debtToEquity'
# ZLSWW 'returnOnAssets'
# ZLSWW 'returnOnEquity'
# ZLSWW 'quickRatio'
# ZLSWW 'currentRatio'
# ZM 'dividendYield'
# ZM 'fiveYearAvgDividendYield'
# ZNTL 'trailingPE'
# ZNTL 'pegRatio'
# ZNTL 'earningsGrowth'
# ZNTL 'revenueGrowth'
# ZNTL 'dividendYield'
# ZNTL 'fiveYearAvgDividendYield'
# ZOM 'overallRisk'
# ZOM 'trailingPE'
# ZOM 'pegRatio'
# ZOM 'earningsGrowth'
# ZOM 'dividendYield'
# ZOM 'fiveYearAvgDividendYield'
# ZS 'trailingPE'
# ZS 'earningsGrowth'
# ZS 'dividendYield'
# ZS 'fiveYearAvgDividendYield'
# ZTEK 'recommendationMean'
# ZTEK 'overallRisk'
# ZTEK 'forwardEps'
# ZTEK 'trailingPE'
# ZTEK 'forwardPE'
# ZTEK 'pegRatio'
# ZTEK 'earningsGrowth'
# ZTEK 'dividendYield'
# ZTEK 'fiveYearAvgDividendYield'
# ZTO 'overallRisk'
# ZTO 'dividendYield'
# ZTO 'fiveYearAvgDividendYield'
# ZTR 'recommendationMean'
# ZTR 'overallRisk'
# ZTR 'forwardEps'
# ZTR 'forwardPE'
# ZTR 'pegRatio'
# ZTR 'dividendYield'
# ZTR 'payoutRatio'
# ZTR 'fiveYearAvgDividendYield'
# ZUMZ 'earningsGrowth'
# ZUMZ 'dividendYield'
# ZUMZ 'fiveYearAvgDividendYield'
# ZUO 'trailingPE'
# ZUO 'pegRatio'
# ZUO 'earningsGrowth'
# ZUO 'dividendYield'
# ZUO 'fiveYearAvgDividendYield'
# ZURA 'overallRisk'
# ZURA 'beta'
# ZURA 'pegRatio'
# ZURA 'earningsGrowth'
# ZURA 'revenueGrowth'
# ZURA 'dividendYield'
# ZURA 'fiveYearAvgDividendYield'
# ZURA 'debtToEquity'
# ZURAW 'sector'
# ZURAW 'industry'
# ZURAW 'recommendationMean'
# ZURAW 'overallRisk'
# ZURAW 'beta'
# ZURAW 'trailingEps'
# ZURAW 'forwardEps'
# ZURAW 'trailingPE'
# ZURAW 'forwardPE'
# ZURAW 'pegRatio'
# ZURAW 'bookValue'
# ZURAW 'priceToBook'
# ZURAW 'ebitdaMargins'
# ZURAW 'profitMargins'
# ZURAW 'earningsGrowth'
# ZURAW 'revenueGrowth'
# ZURAW 'dividendYield'
# ZURAW 'payoutRatio'
# ZURAW 'fiveYearAvgDividendYield'
# ZURAW 'debtToEquity'
# ZURAW 'returnOnAssets'
# ZURAW 'returnOnEquity'
# ZURAW 'quickRatio'
# ZURAW 'currentRatio'
# ZVIA 'overallRisk'
# ZVIA 'trailingPE'
# ZVIA 'earningsGrowth'
# ZVIA 'dividendYield'
# ZVIA 'fiveYearAvgDividendYield'
# ZVRA 'overallRisk'
# ZVRA 'trailingPE'
# ZVRA 'pegRatio'
# ZVRA 'earningsGrowth'
# ZVRA 'dividendYield'
# ZVRA 'fiveYearAvgDividendYield'
# ZVSA 'recommendationMean'
# ZVSA 'overallRisk'
# ZVSA 'beta'
# ZVSA 'forwardEps'
# ZVSA 'trailingPE'
# ZVSA 'forwardPE'
# ZVSA 'pegRatio'
# ZVSA 'earningsGrowth'
# ZVSA 'revenueGrowth'
# ZVSA 'dividendYield'
# ZVSA 'fiveYearAvgDividendYield'
# ZWS 'fiveYearAvgDividendYield'
# ZYME 'overallRisk'
# ZYME 'earningsGrowth'
# ZYME 'dividendYield'
# ZYME 'fiveYearAvgDividendYield'
# ZYNE 'overallRisk'
# ZYNE 'trailingPE'
# ZYNE 'pegRatio'
# ZYNE 'earningsGrowth'
# ZYNE 'revenueGrowth'
# ZYNE 'dividendYield'
# ZYNE 'fiveYearAvgDividendYield'
# ZYXI 'pegRatio'
# ZYXI 'dividendYield'
# ZYXI 'fiveYearAvgDividendYield'
#                             shortName              sector  \
# A          Agilent Technologies, Inc.          Healthcare
# AA                  Alcoa Corporation     Basic Materials
# AAC      Ares Acquisition Corporation  Financial Services
# AACG            ATA Creativity Global  Consumer Defensive
# AACI       Armada Acquisition Corp. I  Financial Services
# ...                               ...                 ...
# ZVSA       ZyVersa Therapeutics, Inc.          Healthcare
# ZWS   Zurn Elkay Water Solutions Corp         Industrials
# ZYME                   Zymeworks Inc.          Healthcare
# ZYNE    Zynerba Pharmaceuticals, Inc.          Healthcare
# ZYXI                      Zynex, Inc.          Healthcare
#
#                                     industry recommendationMean overallRisk  \
# A                     Diagnostics & Research                2.2           8
# AA                                  Aluminum                2.6           1
# AAC                          Shell Companies                NaN         NaN
# AACG           Education & Training Services                2.0         NaN
# AACI                         Shell Companies                NaN         NaN
# ...                                      ...                ...         ...
# ZVSA                           Biotechnology                NaN         NaN
# ZWS           Pollution & Treatment Controls                1.9           3
# ZYME                           Biotechnology                1.9         NaN
# ZYNE  Drug Manufacturers—Specialty & Generic                1.7         NaN
# ZYXI                    Medical Distribution                1.5           7
#
#           beta trailingEps forwardEps trailingPE  forwardPE  ...  \
# A     1.026324        4.53       5.98  28.333334  21.463211  ...
# AA    2.442674       -8.55       3.18        NaN  10.449685  ...
# AAC   0.013452       -0.07      -1.01        NaN -10.524753  ...
# AACG  1.072739       -0.22      -0.99        NaN  -1.232121  ...
# AACI       NaN       -0.59        NaN        NaN        NaN  ...
# ...        ...         ...        ...        ...        ...  ...
# ZVSA       NaN       -2.19        NaN        NaN        NaN  ...
# ZWS    1.11673        0.27       1.12  110.14814  26.553572  ...
# ZYME  0.941461        2.57      -1.33   2.894942  -5.593985  ...
# ZYNE   1.76169       -0.81      -0.61        NaN  -0.579836  ...
# ZYXI  0.594735        0.46       0.55  17.086956  14.290909  ...
#
#      earningsGrowth revenueGrowth dividendYield payoutRatio  \
# A             0.121         0.068        0.0071      0.1916
# AA              NaN        -0.263        0.0118         NaN
# AAC             NaN           NaN           NaN         0.0
# AACG            NaN         0.004           NaN         0.0
# AACI            NaN           NaN           NaN         0.0
# ...             ...           ...           ...         ...
# ZVSA            NaN           NaN           NaN         0.0
# ZWS          -0.291         0.419        0.0094      1.6471
# ZYME            NaN        17.569           NaN         0.0
# ZYNE            NaN           NaN           NaN         0.0
# ZYXI          0.125         0.223           NaN         0.0
#
#      fiveYearAvgDividendYield debtToEquity returnOnAssets returnOnEquity  \
# A                         0.7       50.009        0.10401        0.24782
# AA                        NaN       28.399       -0.01106       -0.22429
# AAC                       NaN          NaN       -0.00911            NaN
# AACG                      NaN       26.451       -0.07631       -0.33159
# AACI                      NaN          NaN       -0.02213            NaN
# ...                       ...          ...            ...            ...
# ZVSA                      NaN        0.087       -0.13853       -0.33597
# ZWS                       NaN       38.134        0.05188        0.05138
# ZYME                      NaN        5.774        0.21186        0.45666
# ZYNE                      NaN        0.709       -0.37412       -0.70408
# ZYXI                      NaN      114.587        0.09032        0.26277
#
#      quickRatio currentRatio
# A         1.546         2.37
# AA        0.692        1.799
# AAC       0.006        0.009
# AACG      0.209        0.231
# AACI      0.033        0.033
# ...         ...          ...
# ZVSA      0.149         0.33
# ZWS       1.511        2.976
# ZYME      6.056        6.334
# ZYNE      4.742        4.951
# ZYXI      6.506        7.631
#
# [7151 rows x 25 columns]

# %%
features.to_csv('./data/features.csv', index=True, index_label='ticker')

# %% [markdown]
# ## Labels
#
# Collect label data from:
#
# - https://www.bestquants.com/2019/11/how-to-web-scrapping-zacks-strong-buy.html
#
# Consider using, to retry requests if necessary:
#
# - https://urllib3.readthedocs.io/en/latest/reference/urllib3.util.html#urllib3.util.Retry

# %%
import requests
from requests.exceptions import HTTPError

def zacks(ticker: str):
    json = { ticker:  None }    
    try:
        response = requests.get('https://quote-feed.zacks.com/index?t=' + ticker)
        response.raise_for_status()
        json = response.json()

    except HTTPError as http_err:
        print(f'HTTP error occurred: {http_err}')
    except Exception as err:
        print(f'Other error occurred: {err}')

    return json

# %%
zacks('MSFT')
# Out:
# {'MSFT': {'source': {'sungard': {'bidasksize': '100x200',
#     'dividend_freq': '4',
#     'prev_close_date': '08/09/2023 16:00:00',
#     'zacks_recommendation': '',
#     'timestamp': '15:59',
#     'exchange': 'NASDAQ',
#     'shares': '',
#     'volatility': '.9',
#     'pos_size': '3058486',
#     'open': '326.47',
#     'yrlow': '213.431',
#     'type': 'S',
#     'yield': '.83',
#     'market_cap': '2394092764140',
#     'ask': '322.94',
#     'dividend': '.68',
#     'dividend_date': '09/14/2023 00:00:00',
#     'earnings': '9.81',
#     'close': '326.05',
#     'day_low': '321.0499',
#     'last_trade_datetime': '08/09/2023 16:00:00',
#     'volume': '22327574',
#     'yrhigh': '366.78',
#     'day_high': '327.11',
#     'bid': '322.4',
#     'name': 'Microsoft Corporation',
#     'pe_ratio': '30.06',
#     'updated': '08/09/2023 16:00:00'},
#    'bats': {'ask_size': '7',
#     'routed': '29152',
#     'last_trade_datetime': '08/09/2023 15:58:02',
#     'matched': '806109',
#     'bid_size': '100',
#     'net_pct_change': 'NULL',
#     'updated': '08/09/2023 15:58:20',
#     'end_mkt_day_price': 'NULL',
#     'ask_price': '322.36',
#     'bid_price': '322.31',
#     'last': '85.87',
#     'pre_after_updated': '08/09/2023 19:58:07',
#     'net_price_change': 'NULL',
#     'pre_after_price': '322.85',
#     'net_change': 'NULL'},
#    'pre': {'after_percent_net_change': '.04',
#     'after_net_change': '12/19/2017 19:58:07'}},
#   'exchange': 'Delayed Data from NSDQ',
#   'dividend_yield': '.83',
#   'last': '322.23',
#   'ticker': 'MSFT',
#   'ticker_type': 'S',
#   'zacks_rank_text': 'Hold',
#   'volume': '22357463',
#   'updated': 'Aug 09, 2023 04:00 PM',
#   'percent_net_change': '-1.1715994479374329090630271430762153044',
#   'zacks_rank': '3',
#   'name': 'Microsoft Corporation',
#   'net_change': '-3.82',
#   'market_time': 'After',
#   'previous_close': '322.23',
#   'SUNGARD_BID': '48.49',
#   'SUNGARD_YRLOW': '34.63',
#   'SUNGARD_PE_RATIO': '2.55',
#   'SUNGARD_DAY_LOW': '2.56',
#   'SUNGARD_MARKET_CAP': '48.345',
#   'FEED_NET_CHANGE': '26-SEP-2014',
#   'BATS_PRE_AFTER_UPDATED': '02-DEC-2014',
#   'SUNGARD_EARNINGS': '.31',
#   'SUNGARD_VOLATILITY': '11-DEC-2014',
#   'SUNGARD_PREV_CLOSE_DATE': '49.05',
#   'BATS_ASK_PRICE': '669597',
#   'SUNGARD_YRHIGH': '50.05',
#   'SUNGARD_DIVIDEND_FREQ': '000',
#   'SUNGARD_VOLUME': '',
#   'SUNGARD_BIDASKSIZE': '45x19',
#   'SUNGARD_YIELD': 'Q',
#   'SUNGARD_DAY_HIGH': '.82',
#   'SUNGARD_ZACKS_RECOMMENDATION': 'S',
#   'SUNGARD_NAME': 'MICROSOFT CP',
#   'SUNGARD_TIMESTAMP': '11:50',
#   'SUNGARD_DIVIDEND_DATE': '853',
#   'BATS_BID_SIZE': '11206',
#   'BATS_BID_PRICE': '1900',
#   'BATS_LAST_TRADE_DATETIME': '46.25',
#   'FEED_VOLUME': '26-SEP-2014',
#   'SUNGARD_SHARES': '8',
#   'SUNGARD_DIVIDEND': '242',
#   'SUNGARD_EXCHANGE': 'NASD',
#   'SUNGARD_TYPE': '19.02',
#   'SUNGARD_LAST_TRADE_DATETIME': '02-DEC-2014',
#   'SUNGARD_UPDATED': '400767.53',
#   'BATS_ROUTED': '02-DEC-2014',
#   'BATS_ASK_SIZE': '02-DEC-2014',
#   'FEED_TICKER': 'MSFT',
#   'SUNGARD_POS_SIZE': '50',
#   'FEED_PERCENT_NET_CHANGE': '48.48',
#   'FEED_SOURCE': '-.14',
#   'BATS_PRE_AFTER_PRICE': '-.288',
#   'BATS_UPDATED': '2700',
#   'FEED_LAST': '46.24',
#   'SUNGARD_ASK': '48.5',
#   'BATS_MATCHED': '',
#   'FEED_UPDATED': '10479795',
#   'SUNGARD_OPEN': '48.84',
#   'SUNGARD_CLOSE': '48.62',
#   'pre_after_net_change': '.62',
#   'pre_after_percent_net_change': '.19',
#   'company_short_name': 'Microsoft',
#   'ticker_market_status': 'CLOSING PRICES',
#   'ap_short_name': 'Microsoft',
#   'company_logo_url': 'https://staticx-tuner.zacks.com/images/stocks-thumb/MSFT.png',
#   'confirmed_reporting_date': '',
#   'pe_f1': '30.06',
#   'expected_reporting_date': '1698105600',
#   'market_status': 'Full Trading Day (Market Closed)',
#   'previous_close_date': '08/09/2023'}}

# %%
labels = pd.DataFrame(index = t, columns=['zacks_rank'])
for idx in labels.index:
    z = zacks(idx)
    try:
        labels.loc[idx, ['zacks_rank']] = z[idx]['zacks_rank']
    except Exception as e:
        print (idx, e)
labels
# Out:
# AACIU 'zacks_rank'
# AACIW 'zacks_rank'
# AAIN 'zacks_rank'
# AAM 'zacks_rank'
# ABLLW 'zacks_rank'
# ACABW 'zacks_rank'
# ACAHU 'zacks_rank'
# ACAHW 'zacks_rank'
# ACBAU 'zacks_rank'
# ACBAW 'zacks_rank'
# ACDCW 'zacks_rank'
# ACGLN 'zacks_rank'
# ACGLO 'zacks_rank'
# ACONW 'zacks_rank'
# ADERW 'zacks_rank'
# ADNWW 'zacks_rank'
# ADOCR 'zacks_rank'
# ADOCW 'zacks_rank'
# ADSEW 'zacks_rank'
# ADTHW 'zacks_rank'
# ADVWW 'zacks_rank'
# AEAEU 'zacks_rank'
# AEAEW 'zacks_rank'
# AEFC 'zacks_rank'
# AENTW 'zacks_rank'
# AEPPZ 'zacks_rank'
# AESC 'zacks_rank'
# AFARU 'zacks_rank'
# AFGB 'zacks_rank'
# AFGC 'zacks_rank'
# AFGD 'zacks_rank'
# AFGE 'zacks_rank'
# AFRIW 'zacks_rank'
# AGBAW 'zacks_rank'
# AGNCL 'zacks_rank'
# AGNCM 'zacks_rank'
# AGNCN 'zacks_rank'
# AGNCO 'zacks_rank'
# AGNCP 'zacks_rank'
# AGRIW 'zacks_rank'
# AIC 'zacks_rank'
# AIMBU 'zacks_rank'
# AIMDW 'zacks_rank'
# AIO 'zacks_rank'
# AIRTP 'zacks_rank'
# AIZN 'zacks_rank'
# AJXA 'zacks_rank'
# AKO 'zacks_rank'
# ALCYU 'zacks_rank'
# ALCYW 'zacks_rank'
# ALSAR 'zacks_rank'
# ALSAW 'zacks_rank'
# ALTUW 'zacks_rank'
# ALVOW 'zacks_rank'
# AMAOU 'zacks_rank'
# AMAOW 'zacks_rank'
# AMPGW 'zacks_rank'
# ANGHW 'zacks_rank'
# ANZUU 'zacks_rank'
# ANZUW 'zacks_rank'
# AOGOW 'zacks_rank'
# APCXW 'zacks_rank'
# APGNW 'zacks_rank'
# APLMW 'zacks_rank'
# APMIU 'zacks_rank'
# APMIW 'zacks_rank'
# APTMU 'zacks_rank'
# APTMW 'zacks_rank'
# APXIW 'zacks_rank'
# AQNA 'zacks_rank'
# AQNB 'zacks_rank'
# AQNU 'zacks_rank'
# AQUNR 'zacks_rank'
# ARBEW 'zacks_rank'
# ARBKL 'zacks_rank'
# AREBW 'zacks_rank'
# ARGD 'zacks_rank'
# ARIZW 'zacks_rank'
# ARKOW 'zacks_rank'
# ARQQW 'zacks_rank'
# ARRWU 'zacks_rank'
# ARRWW 'zacks_rank'
# ARTEW 'zacks_rank'
# ARTLW 'zacks_rank'
# ASBA 'zacks_rank'
# ASCAR 'zacks_rank'
# ASCBR 'zacks_rank'
# ASCBU 'zacks_rank'
# ASPAU 'zacks_rank'
# ASTLW 'zacks_rank'
# ASTSW 'zacks_rank'
# ATAKR 'zacks_rank'
# ATAKU 'zacks_rank'
# ATAKW 'zacks_rank'
# ATCO 'zacks_rank'
# ATCOL 'zacks_rank'
# ATLCL 'zacks_rank'
# ATLCP 'zacks_rank'
# ATMCR 'zacks_rank'
# ATMCW 'zacks_rank'
# ATMVU 'zacks_rank'
# ATNFW 'zacks_rank'
# AURCU 'zacks_rank'
# AURCW 'zacks_rank'
# AUROW 'zacks_rank'
# AUUDW 'zacks_rank'
# AUVIP 'zacks_rank'
# AVPTW 'zacks_rank'
# AWINW 'zacks_rank'
# BAERW 'zacks_rank'
# BANFP 'zacks_rank'
# BBLGW 'zacks_rank'
# BBUC 'zacks_rank'
# BCAN 'zacks_rank'
# BCDAW 'zacks_rank'
# BCSAU 'zacks_rank'
# BCSAW 'zacks_rank'
# BCTXW 'zacks_rank'
# BEATW 'zacks_rank'
# BEEMW 'zacks_rank'
# BENFW 'zacks_rank'
# BEPH 'zacks_rank'
# BEPI 'zacks_rank'
# BF 'zacks_rank'
# BFIIW 'zacks_rank'
# BFRGW 'zacks_rank'
# BFRIW 'zacks_rank'
# BHFAL 'zacks_rank'
# BHFAM 'zacks_rank'
# BHFAN 'zacks_rank'
# BHFAO 'zacks_rank'
# BHFAP 'zacks_rank'
# BHRB 'zacks_rank'
# BHV 'zacks_rank'
# BIAFW 'zacks_rank'
# BIGZ 'zacks_rank'
# BIOSU 'zacks_rank'
# BIOSW 'zacks_rank'
# BIPI 'zacks_rank'
# BKDT 'zacks_rank'
# BLACR 'zacks_rank'
# BLACU 'zacks_rank'
# BLACW 'zacks_rank'
# BLDEW 'zacks_rank'
# BLEUR 'zacks_rank'
# BLEUW 'zacks_rank'
# BML 'zacks_rank'
# BNGOW 'zacks_rank'
# BNH 'zacks_rank'
# BNIXR 'zacks_rank'
# BNIXW 'zacks_rank'
# BOCNW 'zacks_rank'
# BOWNU 'zacks_rank'
# BPOPM 'zacks_rank'
# BPYPM 'zacks_rank'
# BPYPN 'zacks_rank'
# BPYPO 'zacks_rank'
# BPYPP 'zacks_rank'
# BRACR 'zacks_rank'
# BREZR 'zacks_rank'
# BREZW 'zacks_rank'
# BRK 'zacks_rank'
# BRKHW 'zacks_rank'
# BRLIR 'zacks_rank'
# BRLIU 'zacks_rank'
# BRLIW 'zacks_rank'
# BROGW 'zacks_rank'
# BRSHW 'zacks_rank'
# BTB 'zacks_rank'
# BTBDW 'zacks_rank'
# BTMWW 'zacks_rank'
# BTWNU 'zacks_rank'
# BTWNW 'zacks_rank'
# BUJAU 'zacks_rank'
# BWAQR 'zacks_rank'
# BWBBP 'zacks_rank'
# BWNB 'zacks_rank'
# BWSN 'zacks_rank'
# BYNOW 'zacks_rank'
# BYTSU 'zacks_rank'
# BZFDW 'zacks_rank'
# CBH 'zacks_rank'
# CBRGW 'zacks_rank'
# CCAIU 'zacks_rank'
# CCLDO 'zacks_rank'
# CCLDP 'zacks_rank'
# CCNEP 'zacks_rank'
# CCZ 'zacks_rank'
# CDAQU 'zacks_rank'
# CDIOW 'zacks_rank'
# CDZIP 'zacks_rank'
# CEADW 'zacks_rank'
# CELUW 'zacks_rank'
# CETUR 'zacks_rank'
# CETUU 'zacks_rank'
# CETUW 'zacks_rank'
# CETXP 'zacks_rank'
# CFFEU 'zacks_rank'
# CFFEW 'zacks_rank'
# CFFSW 'zacks_rank'
# CFIVW 'zacks_rank'
# CGABL 'zacks_rank'
# CHEAU 'zacks_rank'
# CHEAW 'zacks_rank'
# CHKEL 'zacks_rank'
# CHKEW 'zacks_rank'
# CHKEZ 'zacks_rank'
# CHSCL 'zacks_rank'
# CHSCM 'zacks_rank'
# CHSCN 'zacks_rank'
# CHSCO 'zacks_rank'
# CIFRW 'zacks_rank'
# CINGW 'zacks_rank'
# CITEU 'zacks_rank'
# CITEW 'zacks_rank'
# CLAYW 'zacks_rank'
# CLBTW 'zacks_rank'
# CLINR 'zacks_rank'
# CLINU 'zacks_rank'
# CLNNW 'zacks_rank'
# CLOEU 'zacks_rank'
# CLRCR 'zacks_rank'
# CLRCW 'zacks_rank'
# CLVRW 'zacks_rank'
# CMAXW 'zacks_rank'
# CMPOW 'zacks_rank'
# CMSA 'zacks_rank'
# CMSC 'zacks_rank'
# CMSD 'zacks_rank'
# CNFRL 'zacks_rank'
# CNGLU 'zacks_rank'
# CNOBP 'zacks_rank'
# COEPW 'zacks_rank'
# COMSP 'zacks_rank'
# COMSW 'zacks_rank'
# CONXU 'zacks_rank'
# CONXW 'zacks_rank'
# CPAAU 'zacks_rank'
# CPAAW 'zacks_rank'
# CPTNW 'zacks_rank'
# CRD 'zacks_rank'
# CRESW 'zacks_rank'
# CRGOW 'zacks_rank'
# CSLMR 'zacks_rank'
# CSLMU 'zacks_rank'
# CSLRW 'zacks_rank'
# CSSEL 'zacks_rank'
# CSSEN 'zacks_rank'
# CSSEP 'zacks_rank'
# CSWCZ 'zacks_rank'
# CTBB 'zacks_rank'
# CTCXW 'zacks_rank'
# CTDD 'zacks_rank'
# CUBB 'zacks_rank'
# CUENW 'zacks_rank'
# CURIW 'zacks_rank'
# CXAIW 'zacks_rank'
# CYCCP 'zacks_rank'
# CYTHW 'zacks_rank'
# DATSW 'zacks_rank'
# DAVEW 'zacks_rank'
# DBGIW 'zacks_rank'
# DCF 'zacks_rank'
# DCFCW 'zacks_rank'
# DCOMP 'zacks_rank'
# DDT 'zacks_rank'
# DECA 'zacks_rank'
# DECAU 'zacks_rank'
# DECAW 'zacks_rank'
# DFLIW 'zacks_rank'
# DHACU 'zacks_rank'
# DHACW 'zacks_rank'
# DHCAU 'zacks_rank'
# DHCAW 'zacks_rank'
# DHCNI 'zacks_rank'
# DHCNL 'zacks_rank'
# DISAW 'zacks_rank'
# DISTR 'zacks_rank'
# DISTW 'zacks_rank'
# DKDCW 'zacks_rank'
# DLY 'zacks_rank'
# DMAQR 'zacks_rank'
# DPCSW 'zacks_rank'
# DRCTW 'zacks_rank'
# DRMAW 'zacks_rank'
# DRTSW 'zacks_rank'
# DTB 'zacks_rank'
# DTG 'zacks_rank'
# DTOC 'zacks_rank'
# DTOCW 'zacks_rank'
# DTSTW 'zacks_rank'
# DTW 'zacks_rank'
# DUKB 'zacks_rank'
# DUNEU 'zacks_rank'
# DWACU 'zacks_rank'
# DWACW 'zacks_rank'
# EACPW 'zacks_rank'
# EAI 'zacks_rank'
# ECCC 'zacks_rank'
# ECCV 'zacks_rank'
# ECCW 'zacks_rank'
# ECCX 'zacks_rank'
# ECXWW 'zacks_rank'
# EDBLW 'zacks_rank'
# EFHTR 'zacks_rank'
# EFHTW 'zacks_rank'
# EFSCP 'zacks_rank'
# EFTRW 'zacks_rank'
# EICA 'zacks_rank'
# EICB 'zacks_rank'
# ELC 'zacks_rank'
# EMCGR 'zacks_rank'
# EMCGU 'zacks_rank'
# EMLDU 'zacks_rank'
# EMLDW 'zacks_rank'
# EMP 'zacks_rank'
# ENERR 'zacks_rank'
# ENERW 'zacks_rank'
# ENJ 'zacks_rank'
# ENO 'zacks_rank'
# EOSEW 'zacks_rank'
# EP 'zacks_rank'
# EQRXW 'zacks_rank'
# ESACU 'zacks_rank'
# ESGLW 'zacks_rank'
# ESGRO 'zacks_rank'
# ESGRP 'zacks_rank'
# ESHAR 'zacks_rank'
# ETI 'zacks_rank'
# EUDAW 'zacks_rank'
# EVGOW 'zacks_rank'
# EVGRU 'zacks_rank'
# EVGRW 'zacks_rank'
# EVLVW 'zacks_rank'
# FATBP 'zacks_rank'
# FATBW 'zacks_rank'
# FATPW 'zacks_rank'
# FAZEW 'zacks_rank'
# FBIOP 'zacks_rank'
# FCNCO 'zacks_rank'
# FCNCP 'zacks_rank'
# FCRX 'zacks_rank'
# FEXD 'zacks_rank'
# FEXDR 'zacks_rank'
# FEXDU 'zacks_rank'
# FFIEW 'zacks_rank'
# FGBIP 'zacks_rank'
# FGFPP 'zacks_rank'
# FGIWW 'zacks_rank'
# FGMCW 'zacks_rank'
# FHLTW 'zacks_rank'
# FIACU 'zacks_rank'
# FIACW 'zacks_rank'
# FICVW 'zacks_rank'
# FITBI 'zacks_rank'
# FITBO 'zacks_rank'
# FITBP 'zacks_rank'
# FNVTU 'zacks_rank'
# FORLU 'zacks_rank'
# FORLW 'zacks_rank'
# FOSLL 'zacks_rank'
# FRBNU 'zacks_rank'
# FRBNW 'zacks_rank'
# FREEW 'zacks_rank'
# FRGAP 'zacks_rank'
# FRLAW 'zacks_rank'
# FRMEP 'zacks_rank'
# FRXB 'zacks_rank'
# FSRXW 'zacks_rank'
# FTAIM 'zacks_rank'
# FTAIN 'zacks_rank'
# FTAIO 'zacks_rank'
# FTAIP 'zacks_rank'
# FTIIU 'zacks_rank'
# FTIIW 'zacks_rank'
# FULTP 'zacks_rank'
# FXCOR 'zacks_rank'
# FXCOW 'zacks_rank'
# GAINL 'zacks_rank'
# GAINN 'zacks_rank'
# GAINZ 'zacks_rank'
# GAMCU 'zacks_rank'
# GAMCW 'zacks_rank'
# GBBKR 'zacks_rank'
# GCMGW 'zacks_rank'
# GDEVW 'zacks_rank'
# GDSTU 'zacks_rank'
# GDSTW 'zacks_rank'
# GECCM 'zacks_rank'
# GECCN 'zacks_rank'
# GECCO 'zacks_rank'
# GEGGL 'zacks_rank'
# GFAIW 'zacks_rank'
# GFGDR 'zacks_rank'
# GFGDW 'zacks_rank'
# GGROW 'zacks_rank'
# GHIXW 'zacks_rank'
# GIPRW 'zacks_rank'
# GJH 'zacks_rank'
# GJO 'zacks_rank'
# GJP 'zacks_rank'
# GJR 'zacks_rank'
# GJS 'zacks_rank'
# GJT 'zacks_rank'
# GLLIW 'zacks_rank'
# GLSTW 'zacks_rank'
# GMBLP 'zacks_rank'
# GMBLW 'zacks_rank'
# GMBLZ 'zacks_rank'
# GMFIW 'zacks_rank'
# GMVDW 'zacks_rank'
# GODNU 'zacks_rank'
# GOEVW 'zacks_rank'
# GOODN 'zacks_rank'
# GOODO 'zacks_rank'
# GOVXW 'zacks_rank'
# GPACU 'zacks_rank'
# GPACW 'zacks_rank'
# GPJA 'zacks_rank'
# GRABW 'zacks_rank'
# GREEL 'zacks_rank'
# GROMW 'zacks_rank'
# GRRRW 'zacks_rank'
# GSDWW 'zacks_rank'
# GSMGW 'zacks_rank'
# GTACU 'zacks_rank'
# HAIAW 'zacks_rank'
# HBANL 'zacks_rank'
# HBANM 'zacks_rank'
# HBANP 'zacks_rank'
# HCDIP 'zacks_rank'
# HCDIW 'zacks_rank'
# HCDIZ 'zacks_rank'
# HCMAW 'zacks_rank'
# HCVIU 'zacks_rank'
# HCVIW 'zacks_rank'
# HCXY 'zacks_rank'
# HHGCR 'zacks_rank'
# HHGCU 'zacks_rank'
# HHGCW 'zacks_rank'
# HHRSW 'zacks_rank'
# HLP 'zacks_rank'
# HMACR 'zacks_rank'
# HMACU 'zacks_rank'
# HMACW 'zacks_rank'
# HNNAZ 'zacks_rank'
# HOFVW 'zacks_rank'
# HOLOW 'zacks_rank'
# HOVNP 'zacks_rank'
# HPKEW 'zacks_rank'
# HPLTU 'zacks_rank'
# HPLTW 'zacks_rank'
# HROWL 'zacks_rank'
# HROWM 'zacks_rank'
# HSPOU 'zacks_rank'
# HSPOW 'zacks_rank'
# HTFB 'zacks_rank'
# HTFC 'zacks_rank'
# HTIA 'zacks_rank'
# HTIBP 'zacks_rank'
# HTLFP 'zacks_rank'
# HTOOW 'zacks_rank'
# HTZWW 'zacks_rank'
# HUBCW 'zacks_rank'
# HUBCZ 'zacks_rank'
# HUDAR 'zacks_rank'
# HUMAW 'zacks_rank'
# HWCPZ 'zacks_rank'
# HWELU 'zacks_rank'
# HYMCL 'zacks_rank'
# HYMCW 'zacks_rank'
# HYZNW 'zacks_rank'
# ICR 'zacks_rank'
# ICUCW 'zacks_rank'
# ID 'zacks_rank'
# IGICW 'zacks_rank'
# IGTAR 'zacks_rank'
# IGTAW 'zacks_rank'
# IMACW 'zacks_rank'
# IMAQR 'zacks_rank'
# IMAQU 'zacks_rank'
# IMAQW 'zacks_rank'
# IMPPP 'zacks_rank'
# IMTXW 'zacks_rank'
# INAQW 'zacks_rank'
# INBKZ 'zacks_rank'
# INDIW 'zacks_rank'
# INTEW 'zacks_rank'
# INVZW 'zacks_rank'
# IOACW 'zacks_rank'
# IONR 'zacks_rank'
# IPXXU 'zacks_rank'
# IPXXW 'zacks_rank'
# IRAAW 'zacks_rank'
# ISPOW 'zacks_rank'
# ISRLU 'zacks_rank'
# ISRLW 'zacks_rank'
# ITAQW 'zacks_rank'
# IVCAU 'zacks_rank'
# IVCAW 'zacks_rank'
# IVCBW 'zacks_rank'
# IVCPW 'zacks_rank'
# IVDAW 'zacks_rank'
# IXAQU 'zacks_rank'
# IXAQW 'zacks_rank'
# JAQCU 'zacks_rank'
# JAQCW 'zacks_rank'
# JBK 'zacks_rank'
# JFBRW 'zacks_rank'
# JGGCR 'zacks_rank'
# JGGCW 'zacks_rank'
# JSM 'zacks_rank'
# JSPRW 'zacks_rank'
# JUPWW 'zacks_rank'
# JWSM 'zacks_rank'
# KACLR 'zacks_rank'
# KACLW 'zacks_rank'
# KAVL 'zacks_rank'
# KBNTW 'zacks_rank'
# KCGI 'zacks_rank'
# KERNW 'zacks_rank'
# KITTW 'zacks_rank'
# KKRS 'zacks_rank'
# KMPB 'zacks_rank'
# KPLTW 'zacks_rank'
# KRNLU 'zacks_rank'
# KRNLW 'zacks_rank'
# KTH 'zacks_rank'
# KTN 'zacks_rank'
# KVACU 'zacks_rank'
# KWESW 'zacks_rank'
# KYCHR 'zacks_rank'
# KYCHW 'zacks_rank'
# LANDM 'zacks_rank'
# LANDO 'zacks_rank'
# LANDP 'zacks_rank'
# LBBBW 'zacks_rank'
# LBRDP 'zacks_rank'
# LCAAW 'zacks_rank'
# LCAHU 'zacks_rank'
# LCAHW 'zacks_rank'
# LCFYW 'zacks_rank'
# LEXXW 'zacks_rank'
# LFACW 'zacks_rank'
# LFLYW 'zacks_rank'
# LFMDP 'zacks_rank'
# LGHLW 'zacks_rank'
# LGSTW 'zacks_rank'
# LGVCW 'zacks_rank'
# LIBYW 'zacks_rank'
# LIDRW 'zacks_rank'
# LIFWW 'zacks_rank'
# LIFWZ 'zacks_rank'
# LILMW 'zacks_rank'
# LIVBU 'zacks_rank'
# LIVBW 'zacks_rank'
# LIXTW 'zacks_rank'
# LMDXW 'zacks_rank'
# LNZAW 'zacks_rank'
# LSEAW 'zacks_rank'
# LTCHW 'zacks_rank'
# LTRYW 'zacks_rank'
# LUCYW 'zacks_rank'
# LUNRW 'zacks_rank'
# LVOXW 'zacks_rank'
# LVROW 'zacks_rank'
# MACAU 'zacks_rank'
# MACAW 'zacks_rank'
# MAPSW 'zacks_rank'
# MAQCW 'zacks_rank'
# MBINM 'zacks_rank'
# MBINN 'zacks_rank'
# MBINO 'zacks_rank'
# MBINP 'zacks_rank'
# MBNKP 'zacks_rank'
# MBTCR 'zacks_rank'
# MCAAW 'zacks_rank'
# MCACR 'zacks_rank'
# MCACU 'zacks_rank'
# MCAFR 'zacks_rank'
# MCAGR 'zacks_rank'
# MCLDW 'zacks_rank'
# MCOMW 'zacks_rank'
# MDRRP 'zacks_rank'
# MER 'zacks_rank'
# METCL 'zacks_rank'
# METXW 'zacks_rank'
# MGLD 'zacks_rank'
# MGR 'zacks_rank'
# MGRB 'zacks_rank'
# MGRD 'zacks_rank'
# MHLA 'zacks_rank'
# MHNC 'zacks_rank'
# MINDP 'zacks_rank'
# MLECW 'zacks_rank'
# MMVWW 'zacks_rank'
# MNSBP 'zacks_rank'
# MNTSW 'zacks_rank'
# MOBBW 'zacks_rank'
# MOBQW 'zacks_rank'
# MOBVU 'zacks_rank'
# MOBVW 'zacks_rank'
# MPRAW 'zacks_rank'
# MSBIP 'zacks_rank'
# MTACU 'zacks_rank'
# MTACW 'zacks_rank'
# MTEKW 'zacks_rank'
# MURFU 'zacks_rank'
# MVLAW 'zacks_rank'
# MVSTW 'zacks_rank'
# MYPSW 'zacks_rank'
# NAMSW 'zacks_rank'
# NAN 'zacks_rank'
# NBO 'zacks_rank'
# NBSTW 'zacks_rank'
# NCPLW 'zacks_rank'
# NEOVW 'zacks_rank'
# NETDU 'zacks_rank'
# NEWTL 'zacks_rank'
# NEWTZ 'zacks_rank'
# NIMC 'zacks_rank'
# NIOBW 'zacks_rank'
# NIRWW 'zacks_rank'
# NLSPW 'zacks_rank'
# NMK 'zacks_rank'
# NNAVW 'zacks_rank'
# NOGNW 'zacks_rank'
# NOVVW 'zacks_rank'
# NPABW 'zacks_rank'
# NRACU 'zacks_rank'
# NRACW 'zacks_rank'
# NRSNW 'zacks_rank'
# NRUC 'zacks_rank'
# NRXPW 'zacks_rank'
# NSS 'zacks_rank'
# NTRBW 'zacks_rank'
# NTRSO 'zacks_rank'
# NVACR 'zacks_rank'
# NVACW 'zacks_rank'
# NVVEW 'zacks_rank'
# NWTNW 'zacks_rank'
# NXGLW 'zacks_rank'
# NXPLW 'zacks_rank'
# NYMTL 'zacks_rank'
# NYMTM 'zacks_rank'
# NYMTN 'zacks_rank'
# NYMTZ 'zacks_rank'
# OABIW 'zacks_rank'
# OAKUW 'zacks_rank'
# OCAXW 'zacks_rank'
# OCCIN 'zacks_rank'
# OCCIO 'zacks_rank'
# OCEAW 'zacks_rank'
# OCFCP 'zacks_rank'
# OCSAW 'zacks_rank'
# ODVWW 'zacks_rank'
# OFSSH 'zacks_rank'
# OHAAW 'zacks_rank'
# ONBPO 'zacks_rank'
# ONBPP 'zacks_rank'
# ONFOW 'zacks_rank'
# OPINL 'zacks_rank'
# ORGNW 'zacks_rank'
# OSAAW 'zacks_rank'
# OTMOW 'zacks_rank'
# OTRKP 'zacks_rank'
# OXACU 'zacks_rank'
# OXACW 'zacks_rank'
# OXBRW 'zacks_rank'
# OXLCL 'zacks_rank'
# OXLCM 'zacks_rank'
# OXLCN 'zacks_rank'
# OXLCO 'zacks_rank'
# OXLCP 'zacks_rank'
# OXLCZ 'zacks_rank'
# OXSQG 'zacks_rank'
# OXSQL 'zacks_rank'
# OXSQZ 'zacks_rank'
# OXUSW 'zacks_rank'
# OZKAP 'zacks_rank'
# PACWP 'zacks_rank'
# PARAP 'zacks_rank'
# PAVMZ 'zacks_rank'
# PAYOW 'zacks_rank'
# PBAXU 'zacks_rank'
# PBAXW 'zacks_rank'
# PCCTW 'zacks_rank'
# PCGU 'zacks_rank'
# PCTTU 'zacks_rank'
# PCTTW 'zacks_rank'
# PEGRW 'zacks_rank'
# PEPLW 'zacks_rank'
# PETVW 'zacks_rank'
# PETWW 'zacks_rank'
# PFH 'zacks_rank'
# PFTAU 'zacks_rank'
# PFTAW 'zacks_rank'
# PFXNZ 'zacks_rank'
# PGYWW 'zacks_rank'
# PHUNW 'zacks_rank'
# PIIIW 'zacks_rank'
# PLAOU 'zacks_rank'
# PLAOW 'zacks_rank'
# PLMIW 'zacks_rank'
# PLTNR 'zacks_rank'
# PLTNW 'zacks_rank'
# PNACR 'zacks_rank'
# PNACU 'zacks_rank'
# PNACW 'zacks_rank'
# PNFPP 'zacks_rank'
# POWWP 'zacks_rank'
# PPYAW 'zacks_rank'
# PRH 'zacks_rank'
# PRIF 'zacks_rank'
# PRLHU 'zacks_rank'
# PRLHW 'zacks_rank'
# PROCW 'zacks_rank'
# PRS 'zacks_rank'
# PRSRU 'zacks_rank'
# PRSRW 'zacks_rank'
# PRSTW 'zacks_rank'
# PSNYW 'zacks_rank'
# PTHRU 'zacks_rank'
# PTHRW 'zacks_rank'
# PTIXW 'zacks_rank'
# PTWOW 'zacks_rank'
# PUCKU 'zacks_rank'
# PUCKW 'zacks_rank'
# PWUPU 'zacks_rank'
# PWUPW 'zacks_rank'
# PXSAP 'zacks_rank'
# PXSAW 'zacks_rank'
# PYT 'zacks_rank'
# QDROW 'zacks_rank'
# QOMOW 'zacks_rank'
# QRTEP 'zacks_rank'
# QSIAW 'zacks_rank'
# QVCC 'zacks_rank'
# QVCD 'zacks_rank'
# RBCP 'zacks_rank'
# RCA 'zacks_rank'
# RCACW 'zacks_rank'
# RCB 'zacks_rank'
# RCC 'zacks_rank'
# RCLFU 'zacks_rank'
# RCLFW 'zacks_rank'
# RCRTW 'zacks_rank'
# RDIB 'zacks_rank'
# RELI 'zacks_rank'
# RELIW 'zacks_rank'
# RENEU 'zacks_rank'
# RENEW 'zacks_rank'
# REVBW 'zacks_rank'
# RFACW 'zacks_rank'
# RFM 'zacks_rank'
# RGTIW 'zacks_rank'
# RILYG 'zacks_rank'
# RILYK 'zacks_rank'
# RILYL 'zacks_rank'
# RILYM 'zacks_rank'
# RILYN 'zacks_rank'
# RILYO 'zacks_rank'
# RILYP 'zacks_rank'
# RILYT 'zacks_rank'
# RILYZ 'zacks_rank'
# RMGCU 'zacks_rank'
# RMGCW 'zacks_rank'
# RMPL 'zacks_rank'
# RNWWW 'zacks_rank'
# ROCLW 'zacks_rank'
# ROIVW 'zacks_rank'
# ROSEW 'zacks_rank'
# RSVRW 'zacks_rank'
# RTLPO 'zacks_rank'
# RTLPP 'zacks_rank'
# RUMBW 'zacks_rank'
# RVPHW 'zacks_rank'
# RVSNW 'zacks_rank'
# RWAYL 'zacks_rank'
# RWAYZ 'zacks_rank'
# RWODR 'zacks_rank'
# RWODW 'zacks_rank'
# RZB 'zacks_rank'
# SABRP 'zacks_rank'
# SABSW 'zacks_rank'
# SACC 'zacks_rank'
# SAITW 'zacks_rank'
# SAJ 'zacks_rank'
# SAMAW 'zacks_rank'
# SAT 'zacks_rank'
# SAY 'zacks_rank'
# SAZ 'zacks_rank'
# SBBA 'zacks_rank'
# SBFMW 'zacks_rank'
# SBIGW 'zacks_rank'
# SCCB 'zacks_rank'
# SCCC 'zacks_rank'
# SCCD 'zacks_rank'
# SCCE 'zacks_rank'
# SCCF 'zacks_rank'
# SCCG 'zacks_rank'
# SCE 'zacks_rank'
# SCLXW 'zacks_rank'
# SCRMU 'zacks_rank'
# SCRMW 'zacks_rank'
# SDAWW 'zacks_rank'
# SDHY 'zacks_rank'
# SEAL 'zacks_rank'
# SEATW 'zacks_rank'
# SFB 'zacks_rank'
# SFRWW 'zacks_rank'
# SHCRW 'zacks_rank'
# SHFSW 'zacks_rank'
# SHPWW 'zacks_rank'
# SHUAU 'zacks_rank'
# SIGIP 'zacks_rank'
# SKGRU 'zacks_rank'
# SKGRW 'zacks_rank'
# SLACU 'zacks_rank'
# SLACW 'zacks_rank'
# SLAMU 'zacks_rank'
# SLDPW 'zacks_rank'
# SLGCW 'zacks_rank'
# SLMBP 'zacks_rank'
# SLNAW 'zacks_rank'
# SLNHP 'zacks_rank'
# SLVRU 'zacks_rank'
# SLVRW 'zacks_rank'
# SMAPU 'zacks_rank'
# SMAPW 'zacks_rank'
# SMXWW 'zacks_rank'
# SNAXW 'zacks_rank'
# SNCRL 'zacks_rank'
# SOHOB 'zacks_rank'
# SOHON 'zacks_rank'
# SOHOO 'zacks_rank'
# SOJC 'zacks_rank'
# SOJD 'zacks_rank'
# SOJE 'zacks_rank'
# SOLOW 'zacks_rank'
# SONDW 'zacks_rank'
# SOUNW 'zacks_rank'
# SQFTP 'zacks_rank'
# SQFTW 'zacks_rank'
# SQLLW 'zacks_rank'
# SREA 'zacks_rank'
# SRZNW 'zacks_rank'
# SSSSL 'zacks_rank'
# STIXW 'zacks_rank'
# STRCW 'zacks_rank'
# STRRP 'zacks_rank'
# STSSW 'zacks_rank'
# SURGW 'zacks_rank'
# SVIIU 'zacks_rank'
# SWAGW 'zacks_rank'
# SWSSW 'zacks_rank'
# SWVLW 'zacks_rank'
# SXTPW 'zacks_rank'
# SYTAW 'zacks_rank'
# TALKW 'zacks_rank'
# TBB 'zacks_rank'
# TBC 'zacks_rank'
# TBCPW 'zacks_rank'
# TBLAW 'zacks_rank'
# TBLTW 'zacks_rank'
# TCBIO 'zacks_rank'
# TCBPW 'zacks_rank'
# TEAF 'zacks_rank'
# TECTP 'zacks_rank'
# TELZ 'zacks_rank'
# TETEW 'zacks_rank'
# TFINP 'zacks_rank'
# TFSA 'zacks_rank'
# TGAAW 'zacks_rank'
# THCPW 'zacks_rank'
# THWWW 'zacks_rank'
# TLGYW 'zacks_rank'
# TMCWW 'zacks_rank'
# TMKRW 'zacks_rank'
# TMPOW 'zacks_rank'
# TNONW 'zacks_rank'
# TOIIW 'zacks_rank'
# TPTA 'zacks_rank'
# TRINL 'zacks_rank'
# TRKAW 'zacks_rank'
# TRONW 'zacks_rank'
# TVC 'zacks_rank'
# TVE 'zacks_rank'
# TWLVW 'zacks_rank'
# TYGOW 'zacks_rank'
# UCBIO 'zacks_rank'
# UGIC 'zacks_rank'
# UHGWW 'zacks_rank'
# UKOMW 'zacks_rank'
# UNMA 'zacks_rank'
# UPTDW 'zacks_rank'
# USCTW 'zacks_rank'
# USGOW 'zacks_rank'
# UZD 'zacks_rank'
# UZE 'zacks_rank'
# UZF 'zacks_rank'
# VCXAU 'zacks_rank'
# VCXAW 'zacks_rank'
# VERBW 'zacks_rank'
# VGASW 'zacks_rank'
# VHNAW 'zacks_rank'
# VIASP 'zacks_rank'
# VIEWW 'zacks_rank'
# VIIAU 'zacks_rank'
# VIIAW 'zacks_rank'
# VLYPO 'zacks_rank'
# VLYPP 'zacks_rank'
# VSACW 'zacks_rank'
# VSSYW 'zacks_rank'
# VWEWW 'zacks_rank'
# WAFDP 'zacks_rank'
# WALDW 'zacks_rank'
# WAVSU 'zacks_rank'
# WAVSW 'zacks_rank'
# WESTW 'zacks_rank'
# WGSWW 'zacks_rank'
# WHLRD 'zacks_rank'
# WHLRP 'zacks_rank'
# WINVR 'zacks_rank'
# WKSPW 'zacks_rank'
# WLDSW 'zacks_rank'
# WSBCP 'zacks_rank'
# WTFCM 'zacks_rank'
# WTFCP 'zacks_rank'
# WTMAR 'zacks_rank'
# WVVIP 'zacks_rank'
# WWACU 'zacks_rank'
# WWACW 'zacks_rank'
# XELAP 'zacks_rank'
# XFLT 'zacks_rank'
# XOMAO 'zacks_rank'
# XOMAP 'zacks_rank'
# XOSWW 'zacks_rank'
# XPDBU 'zacks_rank'
# YOTAR 'zacks_rank'
# YOTAW 'zacks_rank'
# YSBPW 'zacks_rank'
# ZAPPW 'zacks_rank'
# ZFOXW 'zacks_rank'
# ZIONL 'zacks_rank'
# ZIONO 'zacks_rank'
# ZIONP 'zacks_rank'
# ZIVOW 'zacks_rank'
# ZLSWW 'zacks_rank'
# ZURAW 'zacks_rank'
#      zacks_rank
# A             3
# AA            3
# AAC
# AACG
# AACI
# ...         ...
# ZVSA
# ZWS           1
# ZYME          3
# ZYNE          3
# ZYXI          4
#
# [7151 rows x 1 columns]

# %%
labels.to_csv('./data/labels.csv', index=True, index_label='ticker')
